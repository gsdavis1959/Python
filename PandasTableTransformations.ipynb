# %%
import pandas as pd
import seaborn as sns

# %%
#Loading dataset example
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sort_values('total_bill').head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2

# %%
#We put our columns in the list and input False value in the ascending parameter to change the sorting direction
tips.sort_values(['size', 'tip'], ascending = False).head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 155       29.85  5.14  Female     No   Sun  Dinner     5

# %%
#I specify the as the column and the both total_bill and tip column as the value
tips.pivot(columns = 'sex', values = ['total_bill', 'tip'])
# Out:
#     total_bill          tip
# sex       Male Female  Male Female
# 0          NaN  16.99   NaN   1.01
# 1        10.34    NaN  1.66    NaN
# 2        21.01    NaN  3.50    NaN
# 3        23.68    NaN  3.31    NaN
# 4          NaN  24.59   NaN   3.61
# ..         ...    ...   ...    ...
# 239      29.03    NaN  5.92    NaN
# 240        NaN  27.18   NaN   2.00
# 241      22.67    NaN  2.00    NaN
# 242      17.82    NaN  1.75    NaN
# 243        NaN  18.78   NaN   3.00
#
# [244 rows x 4 columns]

# %%
tips.pivot_table(columns = 'sex', values = ['total_bill', 'tip'])
# Out:
# sex              Male     Female
# tip          3.089618   2.833448
# total_bill  20.744076  18.056897

# %%
tips.pivot_table(columns = 'sex', values = ['total_bill', 'tip'], aggfunc = ['mean', 'std', 'median'])
# Out:
#                  mean                  std           median
# sex              Male     Female      Male    Female   Male Female
# tip          3.089618   2.833448  1.489102  1.159495   3.00   2.75
# total_bill  20.744076  18.056897  9.246469  8.009209  18.35  16.40

# %%
#Specificed the size column as the index and margins as True to get the total summary
tips.pivot_table(columns = 'sex', values = ['total_bill', 'tip'], aggfunc = ['mean', 'std', 'median'], index = 'size',
                margins = True)
# Out:
#           mean                                 ... median
#            tip                     total_bill  ...    tip total_bill
# sex       Male    Female       All       Male  ...    All       Male  Female     All
# size                                           ...
# 1     1.920000  1.276667  1.437500   8.580000  ...  1.415      8.580   7.250   7.915
# 2     2.614184  2.528448  2.582308  17.104082  ...  2.500     15.750  14.415  15.370
# 3     3.476667  3.250000  3.393158  24.287083  ...  3.290     21.915  17.610  20.365
# 4     4.172143  4.021111  4.135405  28.078214  ...  3.760     25.725  30.140  25.890
# 5     3.750000  5.140000  4.028000  30.122500  ...  5.000     29.305  29.850  29.850
# 6     5.850000  4.600000  5.225000  41.235000  ...  5.000     41.235  28.425  32.050
# All   3.089618  2.833448  2.998279  20.744076  ...  2.900     18.350  16.400  17.795
#
# [7 rows x 18 columns]

# %%
tips.melt(id_vars = 'tip', value_vars = 'sex')
# Out:
#       tip variable   value
# 0    1.01      sex  Female
# 1    1.66      sex    Male
# 2    3.50      sex    Male
# 3    3.31      sex    Male
# 4    3.61      sex  Female
# ..    ...      ...     ...
# 239  5.92      sex    Male
# 240  2.00      sex  Female
# 241  2.00      sex    Male
# 242  1.75      sex    Male
# 243  3.00      sex  Female
#
# [244 rows x 3 columns]

# %%
pd.crosstab(tips['tip'], tips['sex'])
# Out:
# sex    Male  Female
# tip
# 1.00      1       3
# 1.01      0       1
# 1.10      0       1
# 1.17      1       0
# 1.25      2       1
# ...     ...     ...
# 6.70      1       0
# 6.73      1       0
# 7.58      1       0
# 9.00      1       0
# 10.00     1       0
#
# [123 rows x 2 columns]

# %%
pd.crosstab(tips['tip'], tips['sex'],
    rownames=['Tip Amount'], 
    colnames=['Gender']
)
# Out:
# Gender      Male  Female
# Tip Amount
# 1.00           1       3
# 1.01           0       1
# 1.10           0       1
# 1.17           1       0
# 1.25           2       1
# ...          ...     ...
# 6.70           1       0
# 6.73           1       0
# 7.58           1       0
# 9.00           1       0
# 10.00          1       0
#
# [123 rows x 2 columns]

# %%
pd.crosstab(
    tips['smoker'], 
    [tips['sex'], tips['time']]
)
# Out:
# sex     Male        Female
# time   Lunch Dinner  Lunch Dinner
# smoker
# Yes       13     47     10     23
# No        20     77     25     29

# %%
pd.crosstab(tips['smoker'], tips['time'], margins = True)
# Out:
# time    Lunch  Dinner  All
# smoker
# Yes        23      70   93
# No         45     106  151
# All        68     176  244

# %%
pd.crosstab(
    tips['time'], 
    tips['smoker'],
    margins = True, 
    normalize = True
).style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_bd70f86a_7727_11ec_9840_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="index_name level0" >smoker</th>        <th class="col_heading level0 col0" >Yes</th>        <th class="col_heading level0 col1" >No</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >time</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd70f86a_7727_11ec_9840_0242ac1c0002level0_row0" class="row_heading level0 row0" >Lunch</th>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row0_col0" class="data row0 col0" >9.43%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row0_col1" class="data row0 col1" >18.44%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row0_col2" class="data row0 col2" >27.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd70f86a_7727_11ec_9840_0242ac1c0002level0_row1" class="row_heading level0 row1" >Dinner</th>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row1_col0" class="data row1 col0" >28.69%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row1_col1" class="data row1 col1" >43.44%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row1_col2" class="data row1 col2" >72.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_bd70f86a_7727_11ec_9840_0242ac1c0002level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row2_col0" class="data row2 col0" >38.11%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row2_col1" class="data row2 col1" >61.89%</td>
#                         <td id="T_bd70f86a_7727_11ec_9840_0242ac1c0002row2_col2" class="data row2 col2" >100.00%</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(
    tips['smoker'], 
    tips['time'], 
    values = tips['tip'],
    aggfunc = 'mean'
).round(2)
# Out:
# time    Lunch  Dinner
# smoker
# Yes      2.83    3.07
# No       2.67    3.13

# %%
# !pip install itables
# Out:
# Collecting itables
#   Downloading itables-0.4.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from itables) (5.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from itables) (1.1.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->itables) (4.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->itables) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->itables) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->itables) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->itables) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->itables) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->itables) (0.7.0)
# Installing collected packages: itables
# Successfully installed itables-0.4.4

# %%
from itables import init_notebook_mode
init_notebook_mode(all_interactive=True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_html('tips.html')

# %%
# pairwise comparison of two columns in dataframe

from itertools import product
  
# apply product method
list1 = list(product(tips['sex'], tips['time']))
print(list1)
# Out:
# [('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Lunch'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner'), ('Female', 'Dinner' ...

# %%
df = pd.DataFrame (list1, columns = ['sex', 'time'])
print (df)
# Out:
#           sex    time
# 0      Female  Dinner
# 1      Female  Dinner
# 2      Female  Dinner
# 3      Female  Dinner
# 4      Female  Dinner
# ...       ...     ...
# 59531  Female  Dinner
# 59532  Female  Dinner
# 59533  Female  Dinner
# 59534  Female  Dinner
# 59535  Female  Dinner
#
# [59536 rows x 2 columns]

# %%
# update another table's column

# %%
left = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9]
})
left.head()
# Out:
#    a  b   c
# 0  1  4   7
# 1  2  5  10
# 2  3  6  11

# %%
right = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 10, 11]})
right.head()
# Out:
#    a  b   c
# 0  1  4   7
# 1  2  5  10
# 2  3  6  11

# %%
left_a = left.set_index('a')
right_a = right.set_index('a')

# %%
res = left_a.reindex(columns=left_a.columns.union(right_a.columns))
res.update(right_a)
res.reset_index(inplace=True)
res
# Out:
#    a  b   c
# 0  1  4   7
# 1  2  5  10
# 2  3  6  11
