# %%
# !pip install pyecharts==0.5.11
# Out:
# Collecting pyecharts==0.5.11
#   Downloading pyecharts-0.5.11-py2.py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 7.6 MB/s
# Collecting jupyter-echarts-pypkg==0.1.2
#   Downloading jupyter-echarts-pypkg-0.1.2.tar.gz (520 kB)
#      |████████████████████████████████| 520 kB 12.3 MB/s
# Collecting lml==0.0.2
#   Downloading lml-0.0.2-py2.py3-none-any.whl (10 kB)
# Collecting pyecharts-javascripthon==0.0.6
#   Downloading pyecharts_javascripthon-0.0.6-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pyecharts==0.5.11) (7.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyecharts==0.5.11) (0.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyecharts==0.5.11) (2.11.3)
# Collecting pyecharts-jupyter-installer==0.0.3
#   Using cached pyecharts_jupyter_installer-0.0.3-py2.py3-none-any.whl (4.7 kB)
# Collecting javascripthon>=0.10
#   Downloading javascripthon-0.11.tar.gz (540 kB)
#      |████████████████████████████████| 540 kB 19.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from javascripthon>=0.10->pyecharts-javascripthon==0.0.6->pyecharts==0.5.11) (57.4.0)
# Collecting dukpy
#   Downloading dukpy-0.2.3-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 35.2 MB/s
# Collecting macropy3==1.1.0b2
#   Downloading macropy3-1.1.0b2.tar.gz (44 kB)
#      |████████████████████████████████| 44 kB 2.1 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyecharts==0.5.11) (2.0.1)
# Building wheels for collected packages: jupyter-echarts-pypkg, javascripthon, macropy3
#   Building wheel for jupyter-echarts-pypkg (setup.py) ... done
#   Created wheel for jupyter-echarts-pypkg: filename=jupyter_echarts_pypkg-0.1.2-py3-none-any.whl size=522014 sha256=fdeb3b5edf4da7956d49af59a2af1ac74597ea977341a2ad65d0f57192305cc0
#   Stored in directory: /root/.cache/pip/wheels/99/e3/c7/bd39db06900ca320a2fa9e9d155d8c48b5587b7cbffe923fcb
#   Building wheel for javascripthon (setup.py) ... done
#   Created wheel for javascripthon: filename=javascripthon-0.11-py3-none-any.whl size=526642 sha256=152a227690e3d2917c7b08e92d95125f5839699bb6bfe2b39c576bd5e0037927
#   Stored in directory: /root/.cache/pip/wheels/df/41/a1/7b310f6584fdf312da29effe4149ec6c91d5538302147b904d
#   Building wheel for macropy3 (setup.py) ... done
#   Created wheel for macropy3: filename=macropy3-1.1.0b2-py3-none-any.whl size=50109 sha256=67af96e5c9aa81d2433572de0f27393d087588473a3e6d713c6aa684366e474c
#   Stored in directory: /root/.cache/pip/wheels/7c/56/66/4c0cbc078739bf3147d1a1c1cdce40380f693ba2be6aa974d8
# Successfully built jupyter-echarts-pypkg javascripthon macropy3
# Installing collected packages: macropy3, dukpy, pyecharts-jupyter-installer, lml, javascripthon, pyecharts-javascripthon, jupyter-echarts-pypkg, pyecharts
# Successfully installed dukpy-0.2.3 javascripthon-0.11 jupyter-echarts-pypkg-0.1.2 lml-0.0.2 macropy3-1.1.0b2 pyecharts-0.5.11 pyecharts-javascripthon-0.0.6 pyecharts-jupyter-installer-0.0.3

# %%
from pyecharts import Bar

# %%
Bar = Bar("Months Vs Sales of Car", "Various Manufactures")
Bar.add("Mahindra", ['MAY','JUNE','JUL','AUG'], [45,38,20,50], IS_MORE_UTILS = True)
Bar.add("Tata", ['MAY','JUNE','JUL','AUG'], [40,48,38,50], IS_MORE_UTILS = True)
Bar.add("Kia", ['MAY','JUNE','JUL','AUG'], [50,42,15,20], IS_MORE_UTILS = True)
Bar.render('bar.html') # Generates a Bar.html file in the specified directory
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4a835c9a51ed41db95d23b2de2d7ea08" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4a835c9a51ed41db95d23b2de2d7ea08 = echarts.init(document.getElementById('4a835c9a51ed41db95d23b2de2d7ea08'), 'light', {renderer: 'canvas'});
#
# var option_4a835c9a51ed41db95d23b2de2d7ea08 = {
#     "title": [
#         {
#             "text": "Months Vs Sales of Car",
#             "subtext": "Various Manufactures",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8326958,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "Mahindra",
#             "data": [
#                 45,
#                 38,
#                 20,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8326958
#         },
#         {
#             "type": "bar",
#             "name": "Tata",
#             "data": [
#                 40,
#                 48,
#                 38,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8326958
#         },
#         {
#             "type": "bar",
#             "name": "Kia",
#             "data": [
#                 50,
#                 42,
#                 15,
#                 20
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8326958
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Mahindra",
#                 "Tata",
#                 "Kia"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "MAY",
#                 "JUNE",
#                 "JUL",
#                 "AUG"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_4a835c9a51ed41db95d23b2de2d7ea08.setOption(option_4a835c9a51ed41db95d23b2de2d7ea08);
#
#     });
# </script>

# %%
from pyecharts import EffectScatter
es =EffectScatter("Dynamic scatter plot for random X and Y points")
es.add("", [10], [18], symbol_size=20, effect_scale=3.5, effect_period=3, symbol="pin")
es.add("", [20], [9], symbol_size=12, effect_scale=4.5, effect_period=4,symbol="rect")
es.add("", [30], [15], symbol_size=30, effect_scale=5.5, effect_period=5,symbol="roundRect")
es.add("", [40], [40], symbol_size=10, effect_scale=6.5, effect_brushtype='fill',symbol="diamond")
es.add("", [50], [30], symbol_size=16, effect_scale=5.5, effect_period=3,symbol="arrow")
es.add("", [60], [20], symbol_size=6, effect_scale=2.5, effect_period=3,symbol="triangle")
es.render('Scatter.html')

# %%
from pyecharts import Pie
pie =Pie("Pie illustration example", title_pos='center', width=1000, height=600)
pie.add("", ['A', 'B', 'C', 'D', 'E', 'F'], [335, 321, 234, 135, 251, 148], radius=[40, 55],is_label_show=True)
pie.add("", ['H', 'I', 'J'], [335, 679, 204], radius=[0, 30], legend_orient='vertical', legend_pos='left')
pie.render('nested pie.html')

# %%
from pyecharts import Liquid
liquid =Liquid("Waterlevel indication")
liquid.add("Liquid", [0.7328])
liquid.render('water_ball.html')

# %%
from pyecharts import Funnel
Attr = ['Cognitive ',' understand ',' recognized ',' Consider ',' intention ',' purchase ']
value = [120, 100, 80, 60, 40, 20]
Funnel = Funnel('customer purchase analysis')
Funnel.add('Cloth Purchase', Attr, value, is_label_show = True, label_pos = 'inside', legend_orient='vertical', legend_pos='right',label_text_color = '# fff')
Funnel.render('Funnel.html') # Generates files in the specified directory

# %%
from pyecharts import Gauge
gauge = Gauge('project completion progress')
gauge.add('progress table', 'completion rate' , 73.28)
gauge.render('Gauge.html')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="92bd5c3ef0454db6b4ae64cbc1687f43" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_92bd5c3ef0454db6b4ae64cbc1687f43 = echarts.init(document.getElementById('92bd5c3ef0454db6b4ae64cbc1687f43'), 'light', {renderer: 'canvas'});
#
# var option_92bd5c3ef0454db6b4ae64cbc1687f43 = {
#     "title": [
#         {
#             "text": "project completion progress",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2950537,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{a} <br/>{b} : {c}%",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "name": "progress table",
#             "min": 0,
#             "max": 100,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "value": 73.28,
#                     "name": "completion rate"
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "progress table"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_92bd5c3ef0454db6b4ae64cbc1687f43.setOption(option_92bd5c3ef0454db6b4ae64cbc1687f43);
#
#     });
# </script>

# %%
from pyecharts import Line
attr =["Shirt", "T-Shirt", "Jeans", "Kurtas", "Salvar", "Shoes"]
v1 =[5, 20, 36, 10, 10, 100]
v2 =[55, 60, 16, 20, 15, 80]
line =Line("Pacing chart for Shop A and Shop B","X-axis-->Cloths, Y-axis-->Pricing")
line.add("Shop A", attr, v1, mark_point=["average"])
line.add("Shop B", attr, v2, is_smooth=True, mark_line=["max", "average"])
line.render('poly_line.html')

# %%
from pyecharts import Polar
Radius_ =['Monday_','Tuesday_','Wednesday_','Thursday_','Friday_','Saturday_','Sunday_']
po =Polar("Polar_coordinate_system_", width=1200, height=600)
po.add("A", [1, 2, 3, 4, 3, 5, 1], radius_data=Radius_, type='barRadius', is_stack=True)
po.add("B", [2, 4, 6, 1, 2, 3, 1], radius_data=Radius_, type='barRadius', is_stack=True)
po.add("C", [1, 2, 3, 4, 1, 2, 5], radius_data=Radius_, type='barRadius', is_stack=True)
po.render('polar_test.html')

# %%
from pyecharts import Radar
schema =[ ("Sales", 6500), ("management", 16000), ("information Technology", 30000), ("Customer service", 38000), ("Research and development", 52000), ("market", 25000)]
v1 =[[4300, 10000, 28000, 35000, 50000, 19000]]
v2 =[[5000, 14000, 28000, 31000, 42000, 21000]]
radar =Radar()
radar.config(schema)
radar.add("Budget allocation", v1, is_splitline=True, is_axisline_show=True)
radar.add("Actual overhead", v2, label_color=["#4e79a7"], is_area_show=False)
radar.render('rader_test.html')
