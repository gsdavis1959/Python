# %%
import pandas as pd
import numpy as np

# simulated data for widget A
df_a = pd.DataFrame(
    {
        'Month':pd.date_range(
            start = '01-01-2012',
            end = '31-12-2022',
            freq = 'MS'
        ),
        'Quotes':np.random.randint(
            low = 1_000_000,
            high = 2_500_000,
            size = 132
        ),
        'Numbers':np.random.randint(
            low = 300_000,
            high = 500_000,
            size = 132
        ),
        'Amounts':np.random.randint(
            low = 750_000,
            high = 1_250_000,
            size = 132
        )
    }
)

df_a['Product'] = 'A'

# simulated data for widget B
df_b = pd.DataFrame(
    {
        'Month':pd.date_range(
            start = '01-01-2012',
            end = '31-12-2022',
            freq = 'MS'
        ),
        'Quotes':np.random.randint(
            low = 100_000,
            high = 800_000,
            size = 132
        ),
        'Numbers':np.random.randint(
            low = 10_000,
            high = 95_000,
            size = 132
        ),
        'Amounts':np.random.randint(
            low = 450_000,
            high = 750_000,
            size = 132
        )
    }
)

df_b['Product'] = 'B'

# put it together & sort
df = pd.concat([df_a,df_b],axis = 0)
df.sort_values(by = 'Month',inplace = True)
df.reset_index(drop = True,inplace = True)

# %%
# average sale
df['Average sale'] = df['Amounts'] / df['Numbers']

# conversion
df['Product conversion'] = df['Numbers'] / df['Quotes']

# %%
# function to conditionally highlight rows based on product
def highlight_product(s,product,colour = 'yellow'):
    r = pd.Series(data = False,index = s.index)
    r['Product'] = s.loc['Product'] == product
    
    return [f'background-color: {colour}' if r.any() else '' for v in r]

# apply the formatting
df.style\
.apply(highlight_product,product = 'A',colour = '#DDEBF7', axis = 1)\
.format(
    {
        'Month':'{:%b %Y}',
        'Quotes':'{:,.0f}',
        'Numbers':'{:,.0f}',
        'Amounts':'£{:,.0f}',
        'Average sale':'£{:,.2f}',
        'Product conversion':'{:.2%}'
    }
).hide_index()
# Out:
# <style type="text/css">
# #T_e3e44_row0_col0, #T_e3e44_row0_col1, #T_e3e44_row0_col2, #T_e3e44_row0_col3, #T_e3e44_row0_col4, #T_e3e44_row0_col5, #T_e3e44_row0_col6, #T_e3e44_row2_col0, #T_e3e44_row2_col1, #T_e3e44_row2_col2, #T_e3e44_row2_col3, #T_e3e44_row2_col4, #T_e3e44_row2_col5, #T_e3e44_row2_col6, #T_e3e44_row4_col0, #T_e3e44_row4_col1, #T_e3e44_row4_col2, #T_e3e44_row4_col3, #T_e3e44_row4_col4, #T_e3e44_row4_col5, #T_e3e44_row4_col6, #T_e3e44_row6_col0, #T_e3e44_row6_col1, #T_e3e44_row6_col2, #T_e3e44_row6_col3, #T_e3e44_row6_col4, #T_e3e44_row6_col5, #T_e3e44_row6_col6, #T_e3e44_row8_col0, #T_e3e44_row8_col1, #T_e3e44_row8_col2, #T_e3e44_row8_col3, #T_e3e44_row8_col4, #T_e3e44_row8_col5, #T_e3e44_row8_col6, #T_e3e44_row11_col0, #T_e3e44_row11_col1, #T_e3e44_row11_col2, #T_e3e44_row11_col3, #T_e3e44_row11_col4, #T_e3e44_row11_col5, #T_e3e44_row11_col6, #T_e3e44_row13_col0, #T_e3e44_row13_col1, #T_e3e44_row13_col2, #T_e3e44_row13_col3, #T_e3e44_row13_col4, #T_e3e44_row13_col5, #T_e3e44_row13_col6, #T_e3e44_row15_col0, #T_e3e44_row15_col1, #T_e3e44_row15_col2, #T_e3e44_row15_col3, #T_e3e44_row15_col4,
T_e3e44_row48_col5, #T_e3e44_row48_col6, #T_e3e44_row50_col0, #T_e3e44_row50_col1, #T_e3e44_row50_col2, #T_e3e44_row50_col3, #T_e3e44_row50_col4, #T_e3e44_row50_col5, #T_e3e44_row50_col6, #T_e3e44_row53_col0, #T_e3e44_row53_col1, #T_e3e44_row53_col2, #T_e3e44_row53_col3, #T_e3e44_row53_col4, #T_e3e44_row53_col5, #T_e3e44_row53_col6, #T_e3e44_row54_col0, #T_e3e44_row54_col1, #T_e3e44_row54_col2, #T_ ...

# %%
# create a total "row" - i.e. column total
total = df.sum()
total['Month'] = pd.NaT
total['Product'] = ''
total['Average sale'] = total['Amounts'] / total['Numbers']
total['Product conversion'] = total['Numbers'] / total['Quotes']
total = total.to_frame().transpose()
# Out:
# <ipython-input-11-3a3f14feeae4>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total = df.sum()

# %%
# function to highlight the total row
def highlight_total(s):
    r = pd.Series(data = False,index = s.index)
    r['Month'] = pd.isnull(s.loc['Month'])
    
    return ['font-weight: bold' if r.any() else '' for v in r]

# %%
# stack and reset index
d = pd.concat([df,total],axis = 0)
d.reset_index(drop = True,inplace = True)

# apply formatting
d.style\
.set_properties(**{'text-align':'center'})\
.apply(highlight_product,product = 'A',colour = '#DDEBF7',axis = 1)\
.apply(highlight_total,axis = 1)\
.format(
    {
        'Month':'{:%b %Y}',
        'Quotes':'{:,.0f}',
        'Numbers':'{:,.0f}',
        'Amounts':'£{:,.0f}',
        'Average sale':'£{:,.2f}',
        'Product conversion':'{:.2%}'
    },
    na_rep = 'Total'
)\
.set_caption('Sales data <br> Produced by Team X')\
.hide_index()
# Out:
# <style type="text/css">
# #T_186b3_row0_col0, #T_186b3_row0_col1, #T_186b3_row0_col2, #T_186b3_row0_col3, #T_186b3_row0_col4, #T_186b3_row0_col5, #T_186b3_row0_col6, #T_186b3_row2_col0, #T_186b3_row2_col1, #T_186b3_row2_col2, #T_186b3_row2_col3, #T_186b3_row2_col4, #T_186b3_row2_col5, #T_186b3_row2_col6, #T_186b3_row4_col0, #T_186b3_row4_col1, #T_186b3_row4_col2, #T_186b3_row4_col3, #T_186b3_row4_col4, #T_186b3_row4_col5, #T_186b3_row4_col6, #T_186b3_row6_col0, #T_186b3_row6_col1, #T_186b3_row6_col2, #T_186b3_row6_col3, #T_186b3_row6_col4, #T_186b3_row6_col5, #T_186b3_row6_col6, #T_186b3_row8_col0, #T_186b3_row8_col1, #T_186b3_row8_col2, #T_186b3_row8_col3, #T_186b3_row8_col4, #T_186b3_row8_col5, #T_186b3_row8_col6, #T_186b3_row11_col0, #T_186b3_row11_col1, #T_186b3_row11_col2, #T_186b3_row11_col3, #T_186b3_row11_col4, #T_186b3_row11_col5, #T_186b3_row11_col6, #T_186b3_row13_col0, #T_186b3_row13_col1, #T_186b3_row13_col2, #T_186b3_row13_col3, #T_186b3_row13_col4, #T_186b3_row13_col5, #T_186b3_row13_col6, #T_186b3_row15_col0, #T_186b3_row15_col1, #T_186b3_row15_col2, #T_186b3_row15_col3, #T_186b3_row15_col4, #T_186b3_row15_col5, #T_186b3_row15_col6, #T_186b3_row17_col0, #T_186b3_row17_col1, #T_186b3_row17_col2, #T_186b3_row17_col3, #T_186b3_row17_col4, #T_186b3_row17_col5, #T_186b3_row17_col6, #T_186b3_row19_col0, #T_186b3_row19_col1, #T_186b3_row19_col2, #T_186b3_row19_col3, #T_186b3_row19_col4, #T_186b3_row19_col5, #T_186b3_row19_col6, #T_186b3_row20_col0, #T_186b3_row20_col1, #T_186b3_row20_col2, #T_186b3_row20_col3, #T_186b3_row20_col4, #T_186b3_row20_col5, #T_186b3_row20_col6, #T_186b3_row23_col0, #T_186b3_row23_col1, #T_186b3_row23_col2, #T_186b3_row23_col3, #T_186b3_row23_col4, #T_186b3_row23_col5, #T_186b3_row23_col6, #T_186b3_row25_col0, #T_186b3_row25_col1, #T_186b3_row25_col2, #T_186b3_row25_col3, #T_186b3_row25_col4, #T_186b3_row25_col5, #T_186b3_row25_col6, #T_186b3_row27_col0, #T_186b3_row27_col1, #T_186b3_row27_col2, #T_186b3_row27_col3, #T_186b3_row27_col4, #T_186b3_row27_col5, #T_186b3_row27_col6, #T_186b3_row28_col0, #T_186b3_row28_col1, #T_186b3_row28_col2, #T_186b3_row28_col3, #T_186b3_row28_col4, #T_186b3_row28_col5, #T_186b3_row28_col6, #T_186b3_row30_col0, #T_186b3_row30_col1, #T_186b3_row30_col2, #T_186b3_row30_col3, #T_186b3_row30_col4, #T_186b3_row30_col5, #T_186b3_row30_col6, #T_186b3_row33_col0, #T_186b3_row33_col1, #T_186b3_row33_col2, #T_186b3_row33_col3, #T_186b3_row33_col4, #T_186b3_row33_col5, #T_186b3_row33_col6, #T_186b3_row35_col0, #T_186b3_row35_col1, #T_186b3_row35_col2, #T_186b3_row35_col3, #T_186b3_row35_col4, #T_186b3_row35_col5, #T_186b3_row35_col6, #T_186b3_row37_col0, #T_186b3_row37_col1, #T_186b3_row37_col2, #T_186b3_row37_col3, #T_186b3_row37_col4, #T_186b3_row37_col5, #T_186b3_row37_col6, #T_186b3_row39_col0, #T_186b3_row39_col1, #T_186b3_row39_col2, #T_186b3_row39_col3, #T_186b3_row39_col4, #T_186b3_row39_col5, #T_186b3_row39_col6, #T_186b3_row41_col0, #T_186b3_row41_col1, #T_186b3_row41_col2, #T_186b3_row41_col3, #T_186b3_row41_col4, #T_186b3_row41_col5, #T_186b3_row41_col6, #T_186b3_row43_col0, #T_186b3_row43_col1, #T_186b3_row43_col2, #T_186b3_row43_col3, #T_186b3_row43_col4, #T_186b3_row43_col5, #T_186b3_row43_col6, #T_186b3_row44_col0, #T_186b3_row44_col1, #T_186b3_row44_col2, #T_186b3_row44_col3, #T_186b3_row44_col4, #T_186b3_row44_col5, #T_186b3_row44_col6, #T_186b3_row47_col0, #T_186b3_row47_col1, #T_186b3_row47_col2, #T_186b3_row47_col3, #T_186b3_row47_col4, #T_186b3_row47_col5, #T_186b3_row47_col6, #T_186b3_row48_col0, #T_186b3_row48_col1, #T_186b3_row48_col2, #T_186b3_row48_col3, #T_186b3_row48_col4, #T_186b3_row48_col5, #T_186b3_row48_col6, #T_186b3_row50_col0, #T_186b3_row50_col1, #T_186b3_row50_col2, #T_186b3_row50_col3, #T_186b3_row50_col4, #T_186b3_row50_col5, #T_186b3_row50_col6, #T_186b3_row53_col0, #T_186b3_row53_col1, #T_186b3_row53_col2, #T_186b3_row53_col3, #T_186b3_row53_col4, #T_186b3_row53_col5, #T_186b3_row53_col6, #T_186b3_row54_col0, #T_186b3_row54_col1, #T_186b3_row54_col2, #T_ ...
