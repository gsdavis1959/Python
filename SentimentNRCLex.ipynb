# %%
! pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
from textblob import TextBlob
wiki = TextBlob("Python is a high-level, general-purpose programming language.")

# %%
import nltk
nltk.download('punkt')
# !python -m textblob.download_corpora
wiki.tags
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]

# %%
wiki.noun_phrases
# Out:
# WordList(['python'])

# %%
testimonial = TextBlob("Textblob is amazingly simple to use. What great fun!")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.39166666666666666, subjectivity=0.4357142857142857)

# %%
testimonial.sentiment.polarity
# Out:
# 0.39166666666666666

# %%
# !pip install NRCLex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting NRCLex
#   Downloading NRCLex-3.0.0.tar.gz (396 kB)
#      |████████████████████████████████| 396 kB 24.2 MB/s
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (from NRCLex) (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob->NRCLex) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob->NRCLex) (1.15.0)
# Building wheels for collected packages: NRCLex
#   Building wheel for NRCLex (setup.py) ... done
#   Created wheel for NRCLex: filename=NRCLex-3.0.0-py3-none-any.whl size=43329 sha256=efb3afe8d71bff50519abca8e8fe49754ffcd0b41e0e8dc82cfb807ceed11daf
#   Stored in directory: /root/.cache/pip/wheels/af/2c/9c/dfa19d1b65326c520b32850a9311f6d4eda679ac04dba26081
# Successfully built NRCLex
# Installing collected packages: NRCLex
# Successfully installed NRCLex-3.0.0

# %%
from nrclex import NRCLex

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/gsdavis1959/Data/master/ProductReviews.csv')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
str_tweet = ','.join(df['Text'])
text_object = NRCLex(str_tweet)

# %%
data = text_object.raw_emotion_scores
print(data)
# Out:
# {'joy': 416, 'positive': 710, 'trust': 420, 'anticipation': 302, 'surprise': 168, 'negative': 240, 'sadness': 119, 'disgust': 97, 'fear': 104, 'anger': 101}

# %%
emotion_df = pd.DataFrame.from_dict(data, orient='index')
emotion_df.head()
# Out:
#                 0
# joy           416
# positive      710
# trust         420
# anticipation  302
# surprise      168

# %%
motion_df = emotion_df.reset_index()
emotion_df = emotion_df.rename(columns={'index' : 'Emotion Classification' , 0: 'Emotion Count'})
emotion_df = emotion_df.sort_values(by=['Emotion Count'], ascending=False)
emotion_df.head()
# Out:
#               Emotion Count
# positive                710
# trust                   420
# joy                     416
# anticipation            302
# negative                240

# %%
sentences = text_object.sentences
sentences
# Out:
# [Sentence("I have bought several of the Vitality canned dog food products and have found them all to be of good quality."),
#  Sentence("The product looks more like a stew than a processed meat and it smells better."),
#  Sentence("My Labrador is finicky and she appreciates this product better than  most.,Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted."),
#  Sentence("Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".,This is a confection that has been around a few centuries."),
#  Sentence("It is a light, pillowy citrus gelatin with nuts - in this case Filberts."),
#  Sentence("And it is cut into tiny squares and then liberally coated with powdered sugar."),
#  Sentence("And it is a tiny mouthful of heaven."),
#  Sentence("Not too chewy, and very flavorful."),
#  Sentence("I highly recommend this yummy treat."),
#  Sentence("If you are familiar with the story of C.S."),
#  Sentence("Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.,If you are looking for the secret ingredient in Robitussin I believe I have found it."),
#  Sentence("I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda."),
#  Sentence("The flavor is very medicinal.,Great taffy at a great price."),
#  Sentence("There was a wide assortment of yummy taffy."),
#  Sentence("Delivery was very quick."),
#  Sentence("If your a taffy lover, this is a deal.,I got a wild hair for taffy and ordered this five pound bag."),
#  Sentence("The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc."),
#  Sentence("My only complaint is there was a bit too much red/black licorice-flavored pieces (just not my particular favorites)."),
#  Sentence("Between me, my kids, and my husband, this lasted only two weeks!"),
#  Sentence("I would recommend this brand of taffy -- it was a delightful treat.,This saltwater taffy had great flavors and was very soft and chewy."),
#  Sentence("Each candy was individually wrapped well."),
#  Sentence("None of the candies were stuck together, which did happen in the expensive version, Fralinger's."),
#  Sentence("Would highly recommend this candy!"),
#  Sentence("I served it at a beach-themed party and everyone loved it!,This taffy is so good."),
#  Sentence("It is very soft and chewy."),
#  Sentence("The flavors are amazing."),
#  Sentence("I would definitely recommend you buying it."),
#  Sentence("Very satisfying!"),
#  Sentence("!,Right now I'm mostly just sprouting this so my cats can eat the grass."),
#  Sentence("They love it."),
#  Sentence("I rotate it around with Wheatgrass and Rye too,This is a very healthy dog food."),
#  Sentence("Good for their digestion."),
#  Sentence("Also good for small puppies."),
#  Sentence("My dog eats her required amount at every feeding.,I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!"),
#  Sentence("We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!"),
#  Sentence("When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I mean really love hot sauce, but don't want a sauce that tastelessly burns your throat, grab a bottle of Tequila Picante Gourmet de Inclan."),
#  Sentence("Just realize that once you taste it, you will never want to use any other sauce.<br /><br />Thank you for the personal, incredible service!,One of my boys needed to lose some weight and the other didn't."),
#  Sentence("I put this food on the floor for the chubby guy, and the protein-rich, no by-product food up higher where only my skinny boy can jump."),
#  Sentence("The higher food sits going stale."),
#  Sentence("They both really go for this food."),
#  Sentence("And my chubby boy has been losing about an ounce a week.,My cats have been happily eating Felidae Platinum for more than two years."),
#  Sentence("I just got a new bag and the shape of the food is different."),
#  Sentence("They tried the new food when I first put it in their bowls and now the bowls sit full and the kitties will not touch the food."),
#  Sentence("I've noticed similar reviews related to formula changes in the past."),
#  Sentence("Unfortunately, I now need to find a new food that my cats will eat.,good flavor!"),
#  Sentence("these came securely packed... they were fresh and delicious!"),
#  Sentence("i love these Twizzlers!,The Strawberry Twizzlers are my guilty pleasure - yummy."),
#  Sentence("Six pounds will be around for a while with my son and I.,My daughter loves twizzlers and this shipment of six pounds really hit the spot."),
#  Sentence("It's exactly what you would expect...six packages of strawberry twizzlers.,I love eating them and they are good for watching TV and looking at movies!"),
#  Sentence("It is not too sweet."),
#  Sentence("I like to transfer them to a zip lock baggie so they stay fresh so I can take my time eating them.,I am very satisfied with my Twizzler purchase."),
#  Sentence("I shared these with others and we have all enjoyed them."),
#  Sentence("I will definitely be ordering more.,Twizzlers, Strawberry my childhood favorite candy, made in Lancaster Pennsylvania by Y & S Candies, Inc. one of the oldest confectionery Firms in the United States, now a Subsidiary of the Hershey Company, the Company was established in 1845 as Young and Smylie, they also make Apple Licorice Twists, Green Color and Blue Raspberry Licorice Twists, I like them all<br /><br />I keep it in a dry cool place because is not recommended it to put it in the fridge."),
#  Sentence("According to the Guinness Book of Records, the longest Licorice Twist ever made measured 1.200 Feet (370 M) and weighted 100 Pounds (45 Kg) and was made by Y & S Candies, Inc."),
#  Sentence("This Record-Breaking Twist became a Guinness World Record on July 19, 1998."),
#  Sentence("This Product is Kosher!"),
#  Sentence("Thank You,Candy was delivered very fast and was purchased at a reasonable price."),
#  Sentence("I was home bound and unable to get to a store so this was perfect for me.,My husband is a Twizzlers addict."),
#  Sentence("We've bought these many times from Amazon because we're government employees living overseas and can't get them in the country we are assigned to."),
#  Sentence("They've always been fresh and tasty, packed well and arrive in a timely manner.,I bought these for my husband who is currently overseas."),
#  Sentence("He loves these, and apparently his staff likes them also.<br />There are generous amounts of Twizzlers in each 16-ounce bag, and this was well worth the price."),
#  Sentence("<a href="http://www.amazon.com/gp/product/B001GVISJM">Twizzlers, Strawberry, 16-Ounce Bags (Pack of 6)</a>,I can remember buying this candy as a kid and the quality hasn't dropped in all these years."),
#  Sentence("Still a superb product you won't be disappointed with.,I love this candy."),
#  Sentence("After weight watchers I had to cut back but still have a craving for it.,I have lived out of the US for over 7 yrs now, and I so miss my Twizzlers!!"),
#  Sentence("When I go back to visit or someone visits me, I always stock up."),
#  Sentence("All I can say is YUM!<br />Sell these in Mexico and you will have a faithful buyer, more often than I'm able to buy them right now.,Product received is as advertised.<br /><br /><a href="http://www.amazon.com/gp/product/B001GVISJM">Twizzlers, Strawberry, 16-Ounce Bags (Pack of 6)</a>,The candy is just red , No flavor ."),
#  Sentence("Just  plan and chewy ."),
#  Sentence("I would never buy them again,I was so glad Amazon carried these batteries."),
#  Sentence("I have a hard time finding them elsewhere because they are such a unique size."),
#  Sentence("I need them for my garage door opener.<br />Great deal for the price.,I got this for my Mum who is not diabetic but needs to watch her sugar intake, and my father who simply chooses to limit unnecessary sugar intake - she's the one with the sweet tooth - they both LOVED these toffees, you would never guess that they're sugar-free and it's so great that you can eat them pretty much guilt free!"),
#  Sentence("i was so impressed that i've ordered some for myself (w dark chocolate) to take to the office so i'll eat them instead of snacking on sugary sweets.<br />These are just EXCELLENT!,I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!"),
#  Sentence("We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!"),
#  Sentence("When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I mean really love hot sauce, but don't want a sauce that tastelessly burns your throat, grab a bottle of Tequila Picante Gourmet de Inclan."),
#  Sentence("Just realize that once you taste it, you will never want to use any other sauce.<br /><br />Thank you for the personal, incredible service!,I have never been a huge coffee fan."),
#  Sentence("However, my mother purchased this little machine and talked me into trying the Latte Macciato."),
#  Sentence("No Coffee Shop has a better one and I like most of the other products, too (as a usually non-coffee drinker!"),
#  Sentence(").<br />The little Dolche Guesto Machine is super easy to use and prepares a really good Coffee/Latte/Cappuccino/etc in less than a minute (if water is heated up)."),
#  Sentence("I would recommend the Dolce Gusto to anyone."),
#  Sentence("Too good for the price and I'am getting one myself!"),
#  Sentence(":),This offer is a great price and a great taste, thanks Amazon for selling this product.<br /><br />Staral,McCann's Instant Oatmeal is great if you must have your oatmeal but can only scrape together two or three minutes to prepare it."),
#  Sentence("There is no escaping the fact, however, that even the best instant oatmeal is nowhere near as good as even a store brand of oatmeal requiring stovetop preparation."),
#  Sentence("Still, the McCann's is as good as it gets for instant oatmeal."),
#  Sentence("It's even better than the organic, all-natural brands I have tried."),
#  Sentence("All the varieties in the McCann's variety pack taste good."),
#  Sentence("It can be prepared in the microwave or by adding boiling water so it is convenient in the extreme when time is an issue.<br /><br />McCann's use of actual cane sugar instead of high fructose corn syrup helped me decide to buy this product."),
#  Sentence("Real sugar tastes better and is not as harmful as the other stuff."),
#  Sentence("One thing I do not like, though, is McCann's use of thickeners."),
#  Sentence("Oats plus water plus heat should make a creamy, tasty oatmeal without the need for guar gum."),
#  Sentence("But this is a convenience product."),
#  Sentence("Maybe the guar gum is why, after sitting in the bowl a while, the instant McCann's becomes too thick and gluey.,This is a good instant oatmeal from the best oatmeal brand."),
#  Sentence("It uses cane sugar instead of high fructouse corn syrup, so not only does it have a better sweetness, but some doctors now say that this form of sugar is better for you."),
#  Sentence("Great on a cold morning when you don't have time to make McCann's Steel Cut Oats."),
#  Sentence("The apple cinnamon is the best but the maple and brown sugar or the regular are good too."),
#  Sentence("Plus they don't require doctoring to actually tell the three flavors apart.,Instant oatmeal can become soggy the minute the water hits the bowl."),
#  Sentence("McCann's Instant Oatmeal holds its texture, has excellent flavor, and is good for you all at the same time."),
#  Sentence("McCann's regular oat meal is excellent, too, but may take a bit longer to prepare than most have time for in the morning."),
#  Sentence("This is the best instant brand I've ever eaten, and a very close second to the non-instant variety.<br /><br />McCann's Instant Irish Oatmeal, Variety Pack of Regular, Apples & Cinnamon, and Maple & Brown Sugar, 10-Count Boxes (Pack of 6),McCann's Instant Irish Oatmeal, Variety Pack of Regular, Apples & Cinnamon, and Maple & Brown Sugar, 10-Count Boxes (Pack of 6)<br /><br />I'm a fan of the McCann's steel-cut oats, so I thought I'd give the instant variety a try."),
#  Sentence("I found it to be a hardy meal, not too sweet, and great for folks like me (post-bariatric surgery) who need food that is palatable, easily digestible, with fiber but won't make you bloat.,For those of us with celiac disease this product is a lifesaver and what could be better than getting it at almost half the price of the grocery or health food store!"),
#  Sentence("I love McCann's instant oatmeal - all flavors!!"),
#  Sentence("!<br /><br />Thanks,<br />Abby,What else do you need to know?"),
#  Sentence("Oatmeal, instant (make it with a half cup of low-fat milk and add raisins;nuke for 90 seconds)."),
#  Sentence("More expensive than Kroger store brand oatmeal and maybe a little tastier or better texture or something."),
#  Sentence("It's still just oatmeal."),
#  Sentence("Mmm, convenient!,I WAS VISITING MY FRIEND NATE THE OTHER MORNING FOR COFFEE , HE CAME OUT OF HIS STORAGE ROOM WITH ( A PACKET OF McCANNS INSTANT IRISH OATMEAL .)"),
#  Sentence("HE SUGGESTED THAT I TRY IT FOR MY OWN USE ,IN MY STASH ."),
#  Sentence("SOMETIMES NATE DOSE NOT GIVE YOU A CHANCE TO SAY NO , SO I ENDED UP TRYING THE APPLE AND CINN ."),
#  Sentence("FOUND IT TO BE VERY TASTEFULL WHEN MADE WITH WATER OR POWDERED MILK ."),
#  Sentence("IT GOES GOOD WITH O.J."),
#  Sentence("AND COFFEE AND A SLICE OF TOAST AND YOUR READY TO TAKE ON THE WORLD...OR THE DAY AT LEAST..  JERRY REITH...,I ordered this for my wife as it was reccomended by our daughter."),
#  Sentence("She has this almost every morning and likes all flavors."),
#  Sentence("She's happy, I'm happy!!"),
#  Sentence("!<br /><a href="http://www.amazon.com/gp/product/B001EO5QW8">McCANN'S Instant Irish Oatmeal, Variety Pack of Regular, Apples & Cinnamon, and Maple & Brown Sugar, 10-Count Boxes (Pack of 6)</a>,The variety packs taste great!<br /><br />I have them every morning."),
#  Sentence("At $0.30 cents per meal, I don't understand why everyone on earth isn't buying this stuff up.<br /><br />Maple and brown sugar is terrific, followed by apples and cinnamon, followed by regular."),
#  Sentence("You don't get tired of the same ole thing, and they taste great.<br /><br />I just boil water from a small pot, empty the packet or 2 in a bowl, pour in boiling water, and watch it expand to 2x its size!<br /><br />Taste really good and takes minutes to prepare.<br /><br />Not sure why everyone on earth isn't this."),
#  Sentence("Convenient, healthy, very quick, excellent quality, and extremely cheap...,McCann's makes oatmeal for every oatmeal connoisseur, whether one likes it from the raw pellet state that cooks for half an hour, to the sloth addled instant, which can be done in the microwave for under three minutes."),
#  Sentence("It's all good, that's for sure, and the beauty of the instant variety is that it is available in different flavors as well as regular.<br />  This variety pack allows different tastes to be explored, as well as giving you a chance to experience the difference between McCann's and other well-known oatmeals."),
#  Sentence("What I personally like about McCann's is that it cooks up thicker and with more body than the top brand here in America."),
#  Sentence("The Apples & Cinnamon, though, tends to be a little liquidy so you may want to experiment with the amount of water you add."),
#  Sentence("In my 1300watt microwave the oatmeal cooks up in about one minute and twenty-seven seconds, so you should also watch that to get a handle on how much time and water to use.<br />  The only bad thing -- if you can consider it a bad thing -- about this offering is that you have to buy in lot so you'll end up with six ten-count boxes."),
#  Sentence("This is good if you have a whole family of oatmeal-eaters, but if you're a single person alone -- well, love oatmeal.,I have McCann's Oatmeal every morning and by ordering it from Amazon I am able to save almost $3.00 per box.<br />It is a great product."),
#  Sentence("Tastes great and very healthy,McCann's Oatmeal is a good quality choice."),
#  Sentence("Our favorite is the Apples and Cinnamon, but we find that none of these are overly sugary."),
#  Sentence("For a good hot breakfast in 2 minutes, this is excellent.,We really like the McCann's steel cut oats but find we don't cook it up too often.<br />This tastes much better to me than the grocery store brands and is just as convenient.<br />Anything that keeps me eating oatmeal regularly is a good thing.,This seems a little more wholesome than some of the supermarket brands, but it is somewhat mushy and doesn't have quite as much flavor either."),
#  Sentence("It didn't pass muster with my kids, so I probably won't buy it again.,Good oatmeal."),
#  Sentence("I like the apple cinnamon the best."),
#  Sentence("Though I wouldn't follow the directions on the package since it always comes out too soupy for my taste."),
#  Sentence("That could just be me since I like my oatmeal really thick to add some milk on top of.,The flavors are good."),
#  Sentence("However, I do not see any differce between this and Oaker Oats brand - they are both mushy.,I really like the Maple and Brown Sugar flavor."),
#  Sentence("The regular is fine with brown sugar added."),
#  Sentence("The Apples and Cinnamon flavor is OK."),
#  Sentence("This is a very quick, easy and satisfying breakfast and I'll order this brand again, but not the variety."),
#  Sentence("I'll get all Maple and Brown Sugar.,This is the same stuff you can buy at the big box stores."),
#  Sentence("There is nothing healthy about it."),
#  Sentence("It is just carbs and sugars."),
#  Sentence("Save your money and get something that at least has some taste.,This oatmeal is not good."),
#  Sentence("Its mushy, soft, I don't like it."),
#  Sentence("Quaker Oats is the way to go.,Got a free package of these with a bottle of bloody mary mix I bought from the seller, and the advertising worked..lol,  I tried them, and shared them with 2 buddies, and we all loved them..."),
#  Sentence("So im here to buy more, and noticed there were no reviews yet,...  well now there is."),
#  Sentence("They are Hot,  but not "burn your mouth forever hot"  its a nice temp..."),
#  Sentence("Perfect for us..,This wasn't in stock the last time I looked."),
#  Sentence("I had to go to the Vermont Country Store in Weston to find it along with a jaw harp, Cranberry Horseradish Sauce, Fartless Black Bean Salsa, Apple Cider Jelly, Newton's Cradle Art in Motion and the staple Vermont Maple Syrup.<br /><br />Back to the Ass Kickin Peanuts."),
#  Sentence("They are hot."),
#  Sentence("They will activate the perspiration glands behind your ears and under your arms."),
#  Sentence("It requires a beverage as advertised, a glass of very cold milk, and a box of Kleenex since it will make your nose run."),
#  Sentence("They look like ordinary peanuts which is already giving me ideas for work."),
#  Sentence("I suspect that some people have been hitting my goodies in my absence, especially my colleague Greg."),
#  Sentence("I'm going to take this to work at earliest opportunity and empty the contents of this can into an ordinary Planters Peanuts can, and then see whose crying or whose nose is running when I return.<br /><br />The can should be shaken to ensure the spices are evenly distributed."),
#  Sentence("It is important to wash your hands after consumption and not touch the eyes.<br /><br />You'll go nuts over these Ass-Kickin' Peanuts.<br /><br />P.S."),
#  Sentence("I'm not sharing the peanuts, not deliberately, and I'll probably give Greg the jaw harp for Christmas."),
#  Sentence("He'll be so insulted.,we're used to spicy foods down here in south texas and these are not at all spicy."),
#  Sentence("doubt very much habanero is used at all."),
#  Sentence("could take it up a notch or two.,I roast at home with a stove-top popcorn popper (but I do it outside, of course)."),
#  Sentence("These beans (Coffee Bean Direct Green Mexican Altura) seem to be well-suited for this method."),
#  Sentence("The first and second cracks are distinct, and I've roasted the beans from medium to slightly dark with great results every time."),
#  Sentence("The aroma is strong and persistent."),
#  Sentence("The taste is smooth, velvety, yet lively.,We roast these in a large cast iron pan on the grill (about 1/3 of the bag at a time)."),
#  Sentence("The smell is wonderful and the roasted beans taste delicious too."),
#  Sentence("More importantly, the coffee is smooth; no bitter aftertaste."),
#  Sentence("On numerous occasions, we've had to send the roasted beans home with friends because they like it so much.,Deal was awesome!"),
#  Sentence("Arrived before Halloween as indicated and was enough to satisfy trick or treaters."),
#  Sentence("I love the quality of this product and it was much less expensive than the local store's candy.,It is chocolate, what can I say."),
#  Sentence("Great variety of everything our family loves."),
#  Sentence("With a family of six it goes fast here."),
#  Sentence("Perfect variety."),
#  Sentence("Kit Kat, Reeses, take five and more.,Great product, nice combination of chocolates and perfect size!"),
#  Sentence("The bags had plenty, and they were shipped promptly."),
#  Sentence("The kids in the neighborhood liked our candies!,Halloween is over but, I sent a bag to my daughters class for her share."),
#  Sentence("The chocolate was fresh and enjoyed by many.,Watch your prices with this."),
#  Sentence("While the assortment was good, and I did get this on a gold box purchase, the price for this was<br />$3-4 less at Target.,This bag of candy online is pretty expensive, it should be cheaper in order to compete with grocery stores, other than that, its a good combination of my favorite candy,Arrived in 6 days and were so stale i could not eat any of the 6 bags!"),
#  Sentence("!,I have used the endurolyte product for several years in both pill and powder form."),
#  Sentence("Long desert rides on the dirt bike always found my camelbak water heavily laced with the endurolyte powder, not overly tasty, but quite effective, as I never got a cramp on these several hundred mile rides."),
#  Sentence("Same for desert racing in the buggy, the camelbaks were always laced with the powder."),
#  Sentence("Now we have the Fizz...what a great product!"),
#  Sentence("Firstly, its Hammer's endurolyte product so it's great, endurance athlete's the world over use their products."),
#  Sentence("Second its convenient, handly tablets that dissovle in a fizz."),
#  Sentence("Third it tastes great!"),
#  Sentence("Imagine getting a nice cool drink when your body is starving for hydration and electrolytes and rather than getting a "salty" taste, you get a refreshing lemon-lime or mango!"),
#  Sentence("The camelbaks always get the Fizz now."),
#  Sentence("I also drop a tablet in my bottled water whenever I exercise and have a nice flavored water chock full of electrolytes."),
#  Sentence("I cannot recommend this product or any hammer product highly enough.,This product serves me well as a source of electrolytes during and after a long run or bike ride.<br />I have tried all of the flavors but really do like the grapefruit flavor... no after-taste and I actually like the slight carbonation.<br />I use other Hammer products and really like their whole product line.,This stuff really works for preventing cramping during the middle to latter stages of your rides."),
#  Sentence("Pop 1 into each water bottle and you're set."),
#  Sentence("Flavor is fine and goes down easy.,For those of us on a low carb diet these little tablets are just the thing.<br /><br />Two years ago I started cycling again after many years but was having heart arrhythmia after longer rides in high heat."),
#  Sentence("I was drinking plain water but did a little research and thought electrolytes might be the issue."),
#  Sentence("Gatorade wasn't an option because it is so loaded with carbohydrates so I looked around for a low-carb alternative."),
#  Sentence("The "zero carb" sports drinks didn't help so what to do?"),
#  Sentence("One day I ran across these at my bike shop so tried a tube of them.....voila!...problem solved!"),
#  Sentence("!<br /><br />I've shared them with two friends in particular whose problems with leg cramps were resolved while using these.<br /><br />These guys got it right -- they are superbly formulated and simply work.....,I purchased the Mango flavor, and to me it doesn't take like Mango at all."),
#  Sentence("There is no hint of sweetness, and unfortunately there is a hint or aftertaste almost like licorice."),
#  Sentence("I've been consuming various sports nutrition products for decades, so I'm familiar and have come to like the taste of the most of the products I've tried."),
#  Sentence("The mango flavor is one of the least appealing I've tasted."),
#  Sentence("It's not terrible, but it's bad enough that I notice the bad taste every sip I take.,If you're impulsive like me, then $6 is ok. Don't get me wrong, the quality of these babies is very good and I have no complaints."),
#  Sentence("But in retrospect, the price is a little ridiculous (esp."),
#  Sentence("when you add on the shipping).,this was sooooo deliscious but too bad i ate em too fast and gained 2 pds!"),
#  Sentence("my fault,These Albanese gummi bears and rings and so on are very good and tasty and high quality."),
#  Sentence("The bears even have little faces."),
#  Sentence("At my local candy store this type of gummi stuff (bears, rings, snakes, balls, worms, whatever) are about $10/lb."),
#  Sentence("These twin packs of 4.5 or 5 pound bags is a screaming deal as far as I'm concerned."),
#  Sentence("I'm probably 50 pounds deep in these friggin' things."),
#  Sentence("Consumed!,Grape gummy bears are hard to find in my area."),
#  Sentence("In fact pretty much anyone I talk to about grape gummy bears they think I'm lying."),
#  Sentence("So I bought 10lbs... : ) These bears are a little bit bigger then the other brands and have kind of sour kick, but nothing to strong."),
#  Sentence("I love grape flavored candy/soda and these are pretty good."),
#  Sentence("There is another company that makes grape gummy bears that are a little bit better in my opinion, but these are well worth it for the price."),
#  Sentence("I like to use the gummy bears in home made Popsicles with flavored sports drink."),
#  Sentence("The salt in the sports drink makes for softer popsicles, and the gummy bears are awesome frozen."),
#  Sentence("They are delicious!,I ordered two of these and two of raspberry latice tarts directly from FantasiCakes website for a dinner party I was hosting."),
#  Sentence("It arrived fresh and intact."),
#  Sentence("Very good size."),
#  Sentence("I froze half for later use."),
#  Sentence("I am a pastry lover and these were the best I've ever tasted."),
#  Sentence("The pastry was soft, the jam was really good and the taste was great."),
#  Sentence("They were gone in no time."),
#  Sentence("My guests were really impressed.,Buyer Beware Please!"),
#  Sentence("This sweetener is not for everybody."),
#  Sentence("Maltitol is an alcohol sugar and can be undigestible in the body."),
#  Sentence("You will know a short time after consuming it if you are one of the unsuspecting many who cannot digest it by the extreme intestinal bloating and cramping and massive amounts of gas a person can experience."),
#  Sentence("Nausea, diarrhea & headaches can also be experienced."),
#  Sentence("I learned my lesson the hard way years ago when I fell in love with the sugar-free chocolates suzanne sommers used to sell."),
#  Sentence("I thought I'd found sugar-free chocolate nirvana at first taste but the bliss was short lived when the terrible side effects of maltitol kicked in."),
#  Sentence("The discomfort was unlike anything I had ever felt before."),
#  Sentence("I blew up like a balloon and had very painful abdominal cramping."),
#  Sentence("As the symptoms passed, this too was very unpleasant."),
#  Sentence("Though hard for me to believe a low calorie sweetener could be the culprit, all symptoms were gone when I stopped eating the chocolate."),
#  Sentence("My hunch it had something to do with the maltitol were unfortunately confirmed for me about a year later when I purchased some delicious sugar-free popcorn at my local market."),
#  Sentence("The taste was amazing and while I was looking at the label wondering what could possibly make this yummy, new sugarfree treat taste so good, my heart sank when I followed the little asterisk next to sugarfree sweetener* down to the very bottom of the label and read "maltitol" in tiny little letters!"),
#  Sentence("Thank goodness I'd eaten only a little."),
#  Sentence("I still ended up with all the same side-effects but for a much shorter duration."),
#  Sentence("Some people can use maltitol to their heart's content but others, like me, can have a bad reaction to it."),
#  Sentence("In case you're like me, ... it's not you ...it's the maltitol!,It is okay."),
#  Sentence("I would not go out of my way to buy it again,No tea flavor at all."),
#  Sentence("Just whole brunch of artifial flavors."),
#  Sentence("It is not returnable."),
#  Sentence("I wasted 20+ bucks.,These looked like a perfect snack to through in with my trail mix."),
#  Sentence("Unfortunately, they arrived in a solid mass of melted chocolate."),
#  Sentence("I left them in my pantry for a few days, and when I opened them at room temperature they were still gooey."),
#  Sentence("I through them in the fridge and I've been breaking off hunks ever since."),
#  Sentence("They taste good to me, but the chocolate is all grainy after melting and then solidifying again."),
#  Sentence("I won't order them online again, but if I see them in a store I would pick them up.,These taste really good."),
#  Sentence("I have been purchasing a different brand and these are very similar in taste and texture."),
#  Sentence("I agree with the other reviewer regarding ordering in the summer."),
#  Sentence("There is no insulating packaging with ice packs so they will melt in warm weather like all chocolate food items."),
#  Sentence("Order in cold weather and buy enough to last!!"),
#  Sentence("!,The taste was great, but the berries had melted."),
#  Sentence("May order again in winter."),
#  Sentence("If you order in cold weather you should enjoy flavor.,i know i cannot make tea this good."),
#  Sentence("granted, i am not from the south but i know i have never enjoyed tea that was this sweet without being too sweet."),
#  Sentence("it tastes crisp.,This peppermint stick is delicious and fun to eat."),
#  Sentence("My dad got me one for Christmas because he remembered me having a similar one when I was a little girl."),
#  Sentence("I'm 30 now and I love it!,Great gift for all ages!"),
#  Sentence("I purchased these giant canes before and the recipients loved them so much, they kept them and would not eat them.,I know the product title says Molecular Gastronomy, but don't let that scare you off."),
#  Sentence("I have been looking for this for a while now, not for food science, but for something more down to earth."),
#  Sentence("I use it to make my own coffee creamer.<br /><br />I have to have my coffee blonde and sweet - but the flavored creamers are full of the bad kinds of fat, and honestly, I hate to use manufactured "food" items."),
#  Sentence("I really don't think they are good for the body."),
#  Sentence("On the other hand, I hate using cold milk or cream, because I like HOT coffee.<br /><br />I stumbled across this on Amazon one day and got the idea of making my own creamer."),
#  Sentence("I also bought low-fat (non-instant) milk powder and regular milk powder."),
#  Sentence("The non-instant lowfat milk is a little sweeter and tastes fresher than regular instant low-fat milk, but does not dissolve good in cold water - which is not a problem for hot coffee."),
#  Sentence("You will have to play with the ratios - I would not do just the heavy cream, it made the coffee too rich."),
#  Sentence("Also, I think the powder is too expensive to just use on it's own."),
#  Sentence("I like mixing 1/3 of each together.<br /><br />For flavoring, I bough cocoa bean powder, vanilla bean powder, and caster (superfine) sugar."),
#  Sentence("I mix up small batches along with spices like cinnamon and nutmeg to make my own flavored creamers."),
#  Sentence("If you wanted, you could use a fake sweetner powder instead."),
#  Sentence("I make up small amounts that I store in jelly canning jars."),
#  Sentence("I also use my little food chopper/food processor to blend everything, so the sugar is not heavier and sinks to the bottom."),
#  Sentence("Let it settle for a bit before opening the top though.<br /><br />This stuff tastes WAY better than the storebought creamers and it is fun to experiment and come up with your own flavors."),
#  Sentence("I am going to try using some essential oils next and see if I can get a good chocolate/orange mix.<br /><br />All of the ingredients I mentioned are here online."),
#  Sentence("Take the time to experiment."),
#  Sentence("Maybe you don't use any low-fat milk."),
#  Sentence("Or don't add any flavorings."),
#  Sentence("It is up to you."),
#  Sentence("Also, would make great housewarming/host(ess) gifts.<br /><br />I am sure other molecular people will be able to tell you more of what you can do with it, and I am sure I will experiment with it in cooking - but the main reason I bought it was to make my own creamer and it worked out great.,While my dogs like all of the flavors that we have tried of this dog food, for some reason their itching increased when I tried the lamb and rice."),
#  Sentence("I have some very itchy dogs and am giving them a limited ingredient dog food to try to help."),
#  Sentence("The duck and sweet potato cut down on the itching significantly, but when we tried lamb and rice they started itching more once again."),
#  Sentence("I like Natural Balance for the quality ingredients.,Awesome dog food."),
#  Sentence("However, when given to my "Boston", who has severe reactions to some food ingredients; his itching increased to violent jumping out of bed at night, scratching."),
#  Sentence("As soon as I changed to a different formula, the scratching stopped."),
#  Sentence("So glad Natural Balance has other choices."),
#  Sentence("I guess you have to try each, until you find what's best for your pet.,We have three dogs and all of them love this food!"),
#  Sentence("We bought it specifically for one of our dogs who has food allergies and it works great for him, no more hot spots or tummy problems.<br />I LOVE that it ships right to our door with free shipping.,My dog has a ton of allergies both environmental and food."),
#  Sentence("She was on a prescription dog food before we had her tested to see what allergies she has."),
#  Sentence("After we got the test back, we learned she was allergic to something in the prescription brand."),
#  Sentence("So I finally found this dog food and she has done so well on this!"),
#  Sentence("She still has her environmental triggers, but I am happy she can finally eat something I know won't cause her pain.,My shepherd/collie mix has IBS."),
#  Sentence("Our vet recommended a limited ingredient food."),
#  Sentence("This has really helped her symptoms and she likes it."),
#  Sentence("I will always buy it from Amazon...it's $10 cheaper and free shipping!,Natural Balance Dry Dog Food Lamb Meal and Brown Rice Recipe did wonders for my Jack Russell."),
#  Sentence("She has awful food allergy's and this food was our last hope because it was the last food we could find that didn't have SOMETHING in it that she was allergic to."),
#  Sentence("She has no problem eating it dry but normally I mix the Natural Balance Dry Lamb and Brown Rice with the Natural Balance Wet Lamb and Brown Rice.. she seems to like that better."),
#  Sentence("We started feeding it to our other dog (a Bichon) too and she loves it."),
#  Sentence("If your dog has allergy's or stomach issue.. or if you want your dog to eat better food-- this is it!"),
#  Sentence("You will see a difference in your pet.,Great food!"),
#  Sentence("I love the idea of one food for all ages & breeds."),
#  Sentence("ÃŽt's a real convenience as well as a really good product."),
#  Sentence("My 3 dogs eat less, have almost no gas, their poop is regular and a perfect consistency, what else can a mom ask for!"),
#  Sentence("!,I have a standard poodle and pomeranian who both do wonderful on this food."),
#  Sentence("I have switched them to a different food (due to price) a couple of times and end up going right back to natural balance.,This is great dog food, my dog has severs allergies and this brand is the only one that we can feed him.,This food is great - all ages dogs."),
#  Sentence("I have a 3 year old and a puppy."),
#  Sentence("They are both so soft and hardly ever get sick."),
#  Sentence("The food is good especially when you have Amazon Prime shipping  :),My golden retriever is one of the most picky dogs I've ever met."),
#  Sentence("After experimenting with various types of food, I have found she loves natural balance."),
#  Sentence("What I really like about natural balance is the fact that it has multiple flavors in dry and wet varieties."),
#  Sentence("I mix her dry food with a little wet food and my golden loves it."),
#  Sentence("Furthermore, I do like mixing up the flavors each time as I think the same meal day over day might get a little boring, so I figured why not."),
#  Sentence("I tend to stay away from the fish type though as it smells...<br /><br />Additionally, I started purchasing off Amazon because Petco didn't have the wet food box and only had a couple of cans."),
#  Sentence("I came home and to my surprise realized that I could save $20 each time I bought dog food if I just buy it off Amazon.<br /><br />All in all, I definitely recommend and give my stamp of approval to natural balance dog food."),
#  Sentence("While I have never eaten it, my dog seems to love it.,This is the same food we get at pet store."),
#  Sentence("But it's delivered to my door!"),
#  Sentence("And for the same price or slightly less.,I've been very pleased with the Natural Balance dog food."),
#  Sentence("Our dogs have had issues with other dog foods in the past and I had someone recommend Natural Balance grain free since it is possible they were allergic to grains."),
#  Sentence("Since switching I haven't had any issues."),
#  Sentence("It is also helpful that have have different kibble size for larger/smaller sized dogs.,My 1-1/2 year old basenji/jack russell mix loves this dog food."),
#  Sentence("He's been noticeably healthier and more energetic since I switched him over from the standard dog foods earlier this year."),
#  Sentence("Despite the higher cost of natural dog foods, I find that he eats significantly less of the Natural Balance dog foods and still stays happy and full."),
#  Sentence("On the normal dog foods, he'd eat up to 3 cups of dog food a day (the recommended serving for his size), whereas he only eats about 1 cup to 1-1/2 cup of the Natural Balance dog food a day."),
#  Sentence("When you take this into account, you're actually getting more "bang for your buck" with the natural dog foods since you don't have to buy as much to last just as long as the normal dog foods... and a healthier, happier dog, to boot!"),
#  Sentence("Add in the fact that you can get free, 2-day shipping with Amazon Prime..."),
#  Sentence("I'm sold!"),
#  Sentence("!,Our pup has experienced allergies in forms of hotspots and itching from other dog foods."),
#  Sentence("The cheap 'you can buy it anywhere' food not only have crazy preservatives in them but can cause health problems for your pets."),
#  Sentence("This food works wonders on reducing allergies and our dog loves the food.<br />This message is RAMSEY FrAnkenSteiN approved.,My English Bulldog had skin allergies the summer we got him at age 3."),
#  Sentence("The vet recommended we wean him off the food his previous owner gave him (Iams Lamb and Rice) and onto a new kind."),
#  Sentence("This was the second one we tried, and it has been working ever since."),
#  Sentence("It's for dogs that need a limited diet who can be sensitive to additives and proteins commonly found in commercial dog food (like chicken or beef).,I fed this to my Golden Retriever and he hated it."),
#  Sentence("He wouldn't eat it, and when he did, it gave him terrible diarrhea."),
#  Sentence("We will not be buying this again."),
#  Sentence("It's also super expensive.,The mouth says, "How do I love thee, let me count the ways..."<br />If you like apple products a must have item."),
#  Sentence("The only draw back, shipping cost."),
#  Sentence("These are very heavy.,Arrived slightly thawed."),
#  Sentence("My parents wouldn't accept it."),
#  Sentence("However, the company was very helpful and issued a full refund.,The crust on these tarts are perfect."),
#  Sentence("My husband loves these, but I'm not so crazy about them."),
#  Sentence("They are just too sour/tart for my taste."),
#  Sentence("I'll eat the crust and hubby takes my filling."),
#  Sentence("My kids think they're great, so maybe it's just me.,These are absolutely scrumptuous!"),
#  Sentence("My husband and I both love them, however, as another customer put it, they are expensive to ship!"),
#  Sentence("The cost of shipping is more than the tartlets themselves are!,What a nice alternative to an apple pie."),
#  Sentence("Love the fact there was no slicing and dicing."),
#  Sentence("Easy to prepare."),
#  Sentence("I also loved the fact that you can make them fresh whenever needed.,I like Creme Brulee."),
#  Sentence("I loved that these were so easy."),
#  Sentence("Just sprinkle on the sugar that came with and broil."),
#  Sentence("They look amazing and taste great."),
#  Sentence("My guess thought I really went out of the way for them when really it took all of 5 minutes."),
#  Sentence("I will be ordering more!,not what I was expecting in terms of the company's reputation for excellent home delivery products,I first bought pickled asparagus at an Amish market and it was love at first bite."),
#  Sentence("Hence, when I saw these on the discount rack at the local Safeway I cleaned it out."),
#  Sentence("These are even better than the ones from the Amish market."),
#  Sentence("They are fantastic, and some of the jars have a bonus clove of garlic at the bottom."),
#  Sentence("I'm going to order the six pack and I'm a household of one."),
#  Sentence("They wont go to waste!,I love asparagus."),
#  Sentence("Up until very recently, I had never had pickled asparagus."),
#  Sentence("Oh my goodness, when a friend introduced me to this exact brand, I couldn't believe how great stuff tasted."),
#  Sentence("I loved it so much I bought the six pack."),
#  Sentence("I've got 2 jars left."),
#  Sentence("Gonna need more!"),
#  Sentence("!,I'm presently on a diet and I was at my Fresh and Easy Neighborhood Grocery looking over possible diet foods."),
#  Sentence("I wanted things that were tasty, non-fat and low in calories."),
#  Sentence("I came home with about a dozen items."),
#  Sentence("That's how I discovered the Tillen Farms Pickled Crispy Asparagus."),
#  Sentence("Well, I've always liked asparagus anyway and I've enjoyed several brands of pickled asparagus."),
#  Sentence("This Tillen Farms brand is really, really good!"),
#  Sentence("It's the best I can recall."),
#  Sentence("There's an excellent flavor and a big clove of garlic down in  the bottom of the jar which I'm looking forward to eating."),
#  Sentence("I can't believe how good this asparagus tastes and right on the front it says "only 60 calories per jar!""),
#  Sentence("Now this is my idea of a good diet food!<br /><br />Gary Peterson,I was diappointed in the flavor and texture of this mix."),
#  Sentence("I usually like most of the Low Carb things I have tried, but was diappointed in this specific one.,I have been drinking this tea for a long time now."),
#  Sentence("I used to have to purchase it at a doctor's office because it wasn't available elsewhere."),
#  Sentence("I'm so glad that I can buy it now from Amazon.com."),
#  Sentence("I drink this tea throughout the day like other folks drink coffee."),
#  Sentence("Wonderful taste.,I have been drinking Royal King 100% Natural Organic Green Tea (100 tea bags x 2g each) as my every day tea for several years now."),
#  Sentence("I buy 12 boxes at a time to save on shipping."),
#  Sentence("For many years I used to drink coffee from morning till night."),
#  Sentence("But finally I realized that drinking so much coffee was not healthy for me."),
#  Sentence("I finally resolved to improve my health and stopped drinking coffee all together."),
#  Sentence("I tried many alternative drinks to replace my coffee habit."),
#  Sentence("I found that green tea was not only good tasting it also has health benefits."),
#  Sentence("Green tea is one of the few drinks that actually makes you healthier (coffe and other drinks do not) - the only healthier drink is quality cold water."),
#  Sentence("In my opinion, for the price, Royal King 100% Natural Organic Green Tea is one of the best tasting teas."),
#  Sentence("This green tea has a beautiful golden color, the taste is bright and fresh."),
#  Sentence("I recommend adding a tiny amount of Y.S."),
#  Sentence("Organic Bee Farms RAW HONEY to the tea to add sweetness and health benefits too."),
#  Sentence("I also give myself a treat once in a while by having a much more expense tea (Tribute Xi Hu Long Jing) but this fantastic tea is not practical for me to drink as my every day tea (although I would if I could afford it).<br /><br />Cons:  On my latest shipment the package shown on the Amazon page is different than the one shipped."),
#  Sentence("The one shipped displays "NATURALLY HIGH IN POLYPHENOL CATECHINS" (a key contributive element to the possible health effects of tea), whereas the Amazon package displays "CAFFENE FREE"."),
#  Sentence("So I am not sure if this green tea is Caffene free or not."),
#  Sentence("The other con is that sometimes the tea bag rips open when I unwrap the string from around the tea bag."),
#  Sentence("So if the string seems stuck to the tea bag I put the bag in the hot water to unstick it.,this has to be one of the best teas I have ever tasted... it's clean, bright, fresh...<br /><br />great delivery...again quality... just try it...,I love, love this green tea."),
#  Sentence("It is very hard to find in our area and some places on the internet charge a big price and I usually don't get as many boxes as I did with this merchant."),
#  Sentence("I will definitely order from this seller again!!"),
#  Sentence("Thanks!!"),
#  Sentence("I depend on my green tea fix everyday!,I love this tea."),
#  Sentence("It helps curb my eating during the day."),
#  Sentence("My Mom and I have given it all friends to try.,I'm Italian and I lived in Italy for years."),
#  Sentence("I used to buy these cookies for my everyday breakfast with an Italian espresso."),
#  Sentence("I couldn't find them anywhere here in the Bay area, so it's great to have them again.,In the 1980s I spent several summers in Italy."),
#  Sentence("This biscotti is often given as a breakfast food or mid-day snack."),
#  Sentence("They are simple and delicious and were not sold in the US back then."),
#  Sentence("They are so good that I brought back two bags from a recent trip to Italy."),
#  Sentence("It is great to see that they may now be found on Amazon!<br /><br />Note: it is great to open a bag, smell the contents, pour a glass of milk, then dip the Macines in the milk."),
# ...
#  Sentence("I was really surprised as I thought it was a bit better than the other brands and with less seasoning.,these are the best tasting tuna pack they make in my opinion - make a great on the go snack, and really satisfying with the tomato,I have always purchased Star-Kist tuna but thought I would try this brand for a change of pace."),
#  Sentence("The taste of the tuna was not pleasant, too much basil and other spices for me.,I'm not familiar with the Safcol brand but being a tuna addict, gave this a shot."),
#  Sentence("The tuna tastes like it's good quality but I found the tomato basil flavor to be a bit bland."),
#  Sentence("It's better than something plain but it didn't pack the punch I was hoping for."),
#  Sentence("It's still a great option for a low calorie, low fat meal.,I found it much tastier than the plain tuna pouches out there."),
#  Sentence("Excellent quality, and no need to 'dress it up'.<br /><br />I put it the micro on about 20% power for 1 minute and Shazam!<br /><br />I believe a little heating brings out the flavor.,Seriously this product was as tasteless as they come."),
#  Sentence("There are much better tasting products out there but at 100 calories its better than a special k bar or cookie snack pack."),
#  Sentence("You just have to season it or combine it with something else to share the flavor.,I read about pomegranate molasses so I had to try it!"),
#  Sentence("I haven't made anything with it yet, just eaten a little bit at a time but WOW is it decadent!"),
#  Sentence("It's dark, syrupy, sour, and a little sweet."),
#  Sentence("A dab of this and I forget about dessert."),
#  Sentence("It's just a really unique flavor with a pleasing metallic undertone."),
#  Sentence("Yum!!"),
#  Sentence("I'm going to try making fesenjan next :-),Used this in Moroccan recipes, as a syrup in a brilliant mixed beverage and as a swirled topping on sliced oranges soaked in orange water."),
#  Sentence("Wonderful, wonderful stuff!,I don't know how long these sat on the back of a shelf somewhere, but they were so old that they wouldn't cook."),
#  Sentence("I had to throw half of them out, because the skins were damaged, a clear sign of dried beans past their prime."),
#  Sentence("I can't even return these or ask for a refund, because food is not returnable."),
#  Sentence("Will find a different brand to use."),
#  Sentence("For now, I have about fifty servings of beans to throw away.,Besides being smaller than runts, they look the same and have the same consistency."),
#  Sentence("Unfortunately, they taste nothing like banana runts...nor do they even taste good."),
#  Sentence("Yucky stuff."),
#  Sentence("Trying to return with vendor.,The item over all was fine, but the Banana Heads are not just like Banana Runts they are alot smaller."),
#  Sentence("Also when I received the item, the packaging was not great."),
#  Sentence("The Banana Heads had come open during shipping and were all over the packing envelope.,I purchased as a giveaway for a baby shower with Jungle theme!"),
#  Sentence("They worked out perfect for 25 small bags of candy."),
#  Sentence("I purchased 5#."),
#  Sentence("If you want more than 25 small bags, I would purchase a larger bag.,I have drunk Ricore since my mother allowed be to drink caffeine."),
#  Sentence("I love this stuff in milk.<br />It's much smoother and tastier than instant coffee with milk."),
#  Sentence("I am French and live in the US,<br />and bring back boxes of Ricore at every opportunity."),
#  Sentence("Savora is another hidden gem you can bring<br />back."),
#  Sentence("Check it out.,I first had this drink when my mother brought it back with her from a visit to her home in Brittany France and thought it was delicious!"),
#  Sentence("I wish it were a bit cheaper but other than that, I love this product!,I couldn't wait to try the 8&#8243; Cinnamon Coffee Cake because it is made with fresh eggs, creamy sour cream, Madagascar Bourbon Vanilla and is topped and filled with cinnamon streusel."),
#  Sentence("This 8&#8243; Cinnamon Coffee Cake is available online for only $18.95."),
#  Sentence("Now, I have had my fair share of cinnamon coffee cakes, but, let me just tell you that the FantasiCakes Cinnamon Coffee Cake really "takes the cake" with size, price, quality and taste.<br />The cake arrived very fast and was carefully packaged so that it arrived in almost perfect condition."),
#  Sentence("It also comes with a large tub of white icing that you can drizzle over the top, before serving."),
#  Sentence("I couldn't believe how large the size was and it actually fed my family of 5 for us to enjoy during breakfast, for three days."),
#  Sentence("The cake itself is thick and almost has a solid but sponge cake type consistency that is really moist and very filling."),
#  Sentence("The flavors are to die for with the sticky cinnamon outside and sweet cinnamon and vanilla swirled throughout the inside of the cake."),
#  Sentence("The icing really tops it off beautifully and gives it that moist and sticky sweet flavor."),
#  Sentence("Pair the cake with your morning coffee and you've got the perfect breakfast treat!,I used to love these growing up and stopped drinking water and lemon juice from this brand about 5-6 years ago."),
#  Sentence("This stuff used to be so strong i used to just pour some in my mouth and get that alive feeling going."),
#  Sentence("It feels like the product went through changes which added more water or something to make it not so strong."),
#  Sentence("The stronger it is the less you use as well."),
#  Sentence("The product is still really good but the taste is the same quality as the cheaper brand names almost."),
#  Sentence("I thought  these would go fast but hey all lemon stuff i love unless it goes bad."),
#  Sentence("This is a good product just wish it still had that hit me in the mouth chug sensation it used to be like.,One of the best lemon juice that I have tried."),
#  Sentence("I am recurring customer due to the high quality of this product."),
#  Sentence("When the season for fresh lemos is out, this one supplement our need for the citrus on the kitchen or refreshments.<br /><br />I will continue buying it.,This lemon juice is a must in my kitchen year-round."),
#  Sentence("It has a powerful flavor and you don't need much of it to zest up a dish."),
#  Sentence("I add a spritz of it to my water nearly every day.<br /><br />I will buy this product again and again.,Fast delivery and good product."),
#  Sentence("This is the same lemon juice concentrate you can find in stores and it's really handy to have around to add to sauces, dressings, etc."),
#  Sentence("Such a pain to squeeze fresh juice everytime you need it, nevermind having the lemons on hand to begin with.,This is not as good as the Frozen Lemon juice, but it is good."),
#  Sentence("It has a slightly odd flavor, perhaps from a preservative."),
#  Sentence("Sure wish I could order the frozen juice!,Couldn't believe it when told how relaxing this beverage was."),
#  Sentence("Seriously, drink it only if you are getting ready for a nap or bedtime."),
#  Sentence("If you have plans to drive or perform any other activity not recommended.<br /><br />I feel my arms and legs almost tingle with relaxation."),
#  Sentence("After a short time my eyes start to get droopy and I am in another place.<br /><br />Love this stuff.,I bought these at Grocery Outlet here in the Seattle Tacoma are for $4.00 a case of tweleve not paying $38.00 Yes 3 for a dollar."),
#  Sentence("I like the taste not great but not bad either low calorie will buy more but not at this whacked out price.,This is an great product."),
#  Sentence("The taste is great, and it works exactly as described."),
#  Sentence("Superb natural sleep aid."),
#  Sentence("AMAZING!,WE have been looking for "natural" ways to help us sleep since we always seem to be overloaded with stress and a busy schedule."),
#  Sentence("Yes, we'd probably be better served taking a yoga class, but this is a good second choice."),
#  Sentence("This helps you fall asleep and stay asleep."),
#  Sentence("I drank half the first night and that was plenty for me."),
#  Sentence("After about 30 minutes, I was ready for bed!"),
#  Sentence("I woke up refreshed and with no sleepy-drug hangover, so that is a huge bonus.<br /><br />I gave the product 3 stars (instead of the 5 it deserves) as their packing job was marginal at best."),
#  Sentence("The product arrived with 2 broken bottles, which at this price is a $6 loss!"),
#  Sentence("The bottles are glass and all they did was wrap one layer of the small-bubbled bubble wrap around the case and placed it in a larger box with extra room to move around in that box."),
#  Sentence("Big packing fail, but the product is awesome.,We made chocolate chip cookies with BRM Garbanzo Bean Flour and the results were fantastic!"),
#  Sentence("The brown sugar and chocolate mask any bean taste that other reviews have mentioned."),
#  Sentence("Our friends couldn't discern any difference from classic CCCs."),
#  Sentence("The texture, body, and elasticity (meaning reduced tendency to fall apart that occurs with most other gluten-free flours) is nice and chewy -- the same as CCCs made with regular flour."),
#  Sentence("And an added bonus -- the high protein and fiber level (I calculate 2-3 g fiber/cookie) fills you up so that you are satisfied with smaller servings and the glycemic index is significantly lower.<br /><br />I highly recommend this flour even if CCCs are the only thing you make with it.,This  is great stuff."),
#  Sentence("Made some really tasty banana bread."),
#  Sentence("Good quality and lowest price in town.,We had trouble finding this locally - delivery was fast, no more hunting up and down the flour aisle at our local grocery stores.,This packet of glaze is the secret to making those European style fresh fruit tarts."),
#  Sentence("I am about to make one for a pie auction at church, after a friend requested that something "strawberry" should be offered."),
#  Sentence("You can make the most amazing and relatively "healthy" fruit tarts by baking a base, layering it with uncooked, fresh, sliced fruit, then pouring over the made-up contents of one of these packets."),
#  Sentence("They harden up at room temperature, hold the fruit together so you can slice the tart, and they let the beauty of the arranged fruit show through."),
#  Sentence("I've also seen this glaze used over cheesecakes, to hold a fruit topping in place."),
#  Sentence("Personally, I do not like cheesecake (too rich for me) but a fruit glazed cheesecake is gorgeous, I will admit."),
#  Sentence("To do this, slice fruit and layer it on the cheesecake while it's still in the springform pan."),
#  Sentence("Pour on the glaze, let it set up and then remove the springform."),
#  Sentence("You'll have a clear layer of fruit on top of the cheesecake."),
#  Sentence("Cherries, strawberries or sliced mangos are nice, but the best one I ever had used thin slices of lemons, that had been gently poached in sugar syrup before they were layered on the cake.<br /><br />I use a base of sponge cake, baked in a shallow form, but other bases can be pate sucre  (a kind of French pastry that is a bit like a sugar cookie) that works well in those fluted, straight-sided forms."),
#  Sentence("You can also make mini-tarts in a muffin pan, pre-baking each mold with a layer of pie crust (even commercial crust works, though again, I prefer pate sucre, it holds its shape better and is more substantial and has a better crumb.)"),
#  Sentence("Just blind-bake the muffin tins lined with pate, then pop them out and fill with fresh fruits (berries are great) and pour over the glaze."),
#  Sentence("Some people put a layer of creme patisserie, which is a pastry cream like custard but stabilized with flour,  below the fruit and I happen to think these taste best.<br /><br />If you get into baking, this glaze is a must-have on the shelf."),
#  Sentence("The ingredients are vegan: tapioca starch, carrageenan, dextrose, cream of tartar, locust bean gum, so if you are looking to make a vegan tofu cheesecake, you can use this on top, as well as use it for fruit tarts with a nut crust base.,My Scotties were full of hot spots and when I used this within a week all the hot spots were gone."),
#  Sentence("The smell is kinda strong, but not bad."),
#  Sentence("It's tolerablel.,I bought this coffee because its much cheaper than the ganocafe and has the organic reishi mushroom as well as other healthy antioxidants."),
#  Sentence("I didn't expect it to taste good, but it actually does!"),
#  Sentence("I've only had it for a few days and for $5 its totally worth it."),
#  Sentence("My sisters all take ganocafe but now I'm introducing them to this less expensive similar coffee."),
#  Sentence("I will follow up on this product in a few weeks."),
#  Sentence(":),The coffee is very finely processed and the flavor is just alright."),
#  Sentence("Nescafe and Mount Hagen are better - I bought this to try something other than these two, but I probably won't get this again."),
#  Sentence("There is just a slight "vitaminy" taste, but it's not overwhelming."),
#  Sentence("It's also a bit pricey for what you get.,This coffee is great because it's all organic ingredients!"),
#  Sentence("No pesticides to worry about, plus it tastes good, and you have the healing effects for ganoderma.,Like the other people mentioned, this coffee has a great taste."),
#  Sentence("I've tried different instant coffees before, but this one is one of the better ones."),
#  Sentence("Another one of my favorites, if you want to try it out (though NOT organic), is 'Africafe pure instant coffee',Tastes great, and gives me energy without the jitters."),
#  Sentence("Love this product.<br />However, I do wish it came in some sort of resealable jar or hard plastic container instead of a zip-lock pouch because the zip-lock ripped off and quit working after awhile."),
#  Sentence("But the product is fantastic, just not crazy about the packaging.,These little guys are tasty and refreshing.<br /><br />I usually eat salads for lunch which can do terrible things to breath."),
#  Sentence("I eat 2 of these after lunch (because they are so small) and I find this sufficiently resolves the problem.<br /><br />They're sugar free (sugar can actually help the smelly bacteria grow) which is great and they're tasty enough that I almost think of them as part of my lunch.<br /><br />This is a good bulk value buy and I'd highly recommend the mints themselves."),
#  Sentence("Cheers!,I like these better than the regular Altoids, but they're even more costly, so you'd better like them.,These little tins of sugar free mine mints were a great deal.There perfict for on the go.Fifty mints per tin is just the right amount to cary along.And there safer for your teeth than the ones with sugar.The price of twelve dollars was very resonable.Also there great for shareing.If you are looking for a mint try these ones.Youll be glad you did.,Pros:<br />+packaging, shipping, price<br />+sold about a year before its expiration date (enough for me to eat/share 9 boxes)<br />+not too "fresh" like the regular wintergreen and not in a powdery form."),
#  Sentence("it's a real mint!<br /><br />Cons: none!,Be careful not to eat too many of them in one day, as one of the chemicals in it is the same as that of a LAXATIVE!!!"),
#  Sentence("LOLOLOL!!"),
#  Sentence("!,These mints are really strong and have a great taste."),
#  Sentence("They are also a convenient size to carry in a pocket or purse.,This is a huge supply of them."),
#  Sentence("I'm still working on these and have plenty to spare."),
#  Sentence("Much more effective than buying one from the grocery store or 7-11 every time you want a mint.")]

# %%
sentence_df = pd.DataFrame.from_list(sentences, orient='index')
sentence_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-076d337a2367> in <module>()
# ----> 1 sentence_df = pd.DataFrame.from_list(sentences, orient='index')
#       2 sentence_df.head()
#
# AttributeError: type object 'DataFrame' has no attribute 'from_list'

# %%
str_tweet = ','.join(df['Text'])
print(str_tweet)
# Out:
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.,Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".,This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.,If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.,Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.,I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there was a bit too much red/black licorice-flavored pieces (just not my particular favorites). Between me, my kids, and my husband, this lasted only two weeks! I would recommend this brand of taffy -- it was a delightful treat.,This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, Fralinger's.  Would highly recommend this candy!  I served it at a beach-themed party and everyone loved it!,This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!,Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too,This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.,I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!  We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!  When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I mean really love hot sauce, but don't want a sauce that tastelessly burns your throat, grab a bottle of Tequila Picante Gourmet de Inclan.  Just realize that once you taste it, you will never want to use any other sauce.<br /><br />Thank you for the personal, incredible service!,One of my boys needed to lose some weight and the other didn't.  I put this food on the floor for the chubby guy, and the protein-rich, no by-product food up higher where only my skinny boy can jump.  The higher food sits going stale.  They both really go for this food.  And my chubby boy has been losing about an ounce a week.,My cats have been happily eating Felidae Platinum for more than two years. I just got a new bag and the shape of the food is different. They tried the new food when I first put it in their bowls and now the bowls sit full and the kitties will not touch the food. I've noticed similar reviews related to formula changes in the past. Unfortunately, I now need to find a new food that my cats will eat.,good flavor! these came securely ...

# %%
text_object = NRCLex(str_tweet)

# %%
sentences = text_object.affect_list
#sentence_df = pd.DataFrame.from_list(sentences, orient='index')
print(sentences)
# Out:
# ['joy', 'positive', 'trust', 'joy', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'negative', 'negative', 'sadness', 'anticipation', 'positive', 'disgust', 'fear', 'negative', 'sadness', 'positive', 'disgust', 'positive', 'trust', 'anger', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust', 'positive', 'trust', 'anger', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust', 'trust', 'joy', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'positive', 'anticipation', 'joy', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'negative', 'surprise', 'anger', 'negative', 'joy', 'positive', 'anger', 'negative', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'trust', 'anger', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust', 'anticipation', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'positive', 'trust', 'positive', 'joy', 'positive', 'positive', 'joy', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'negative', 'positive', 'surprise', 'anger', 'joy', 'positive', 'trust', 'surprise', 'fear', 'negative', 'sadness', 'anticipation', 'joy', 'positive', 'surprise', 'joy', 'positive', 'anger', 'joy', 'positive', 'anger', 'anger', 'negative', 'trust', 'anger', 'disgust', 'fear', 'negative', 'sadness', 'surprise', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust', 'joy', 'positive', 'trust', 'joy', 'positive', 'trust', 'disgust', 'negative', 'joy', 'positive', 'joy', 'positive', 'trust', 'negative', 'joy', 'positive', 'trust', 'disgust', 'negative', 'anger', 'negative', 'sadness', 'joy', 'positive', 'positive', 'joy', 'positive', 'trust', 'joy', 'positive', 'trust', 'positive', 'joy', 'positive', 'trust', 'trust', 'positive', 'trust', 'joy', 'positive', 'trust', 'positive', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'joy', 'positive', 'joy', 'positive', 'anger', 'negative', 'sadness', 'joy', 'positive', 'anger', 'negative', 'anticipation', 'positive', 'surprise', 'trust', 'joy', 'positive', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'negative', 'anticipation', 'joy', 'positive', 'joy', 'positive', 'joy', 'positive', 'trust', 'joy', 'positive', 'positive', 'positive', 'trust', 'negative', 'negative', 'sadness', 'anticipation', 'positive', 'anticipation', 'joy', 'positive', 'trust', 'fear', 'negative', 'positive', 'anticipation', 'positive', 'joy', 'positive', 'trust', 'positive', 'positive', 'anger', 'disgust', 'negative', 'sadness', 'joy', 'positive', 'anticipation', 'disgust', 'fear', 'joy', 'negative', 'positive', 'sadness', 'surprise', 'trust', 'anticipation', 'positive', 'positive', 'trust', 'positive', 'anticipation', 'anticipation', 'joy', 'positive', 'anticipation', 'positive', 'surprise', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'anticipation', 'fear', 'positive', 'trust', 'positive', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'surprise', 'positive', 'anticipation', 'joy', 'positive', 'trust', 'disgust', 'negative', 'sadness', 'sadness', 'anticipation', 'joy', 'positive', 'trust', 'positive', 'anticipation', 'joy', 'positive', 'positive', 'surprise', 'anger', 'joy', 'positive', 'trust', 'surprise', 'fear', 'negative', 'sadness', 'anticipation', 'joy', 'positive', 'surprise', 'joy', 'positive', 'anger', 'joy', 'positive', 'anger', 'anger', 'negative', 'trust', 'anticipation', 'joy', 'negative', 'positive', 'sadness', 'trust', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'positive', 'anticipation', 'positive', 'trust', 'anticipation', 'joy', 'positive', 'surprise', 'trust', 'anticipation', 'positive ...

# %%
data = text_object.raw_emotion_scores

# %%
emotion_df = pd.DataFrame.from_dict(data, orient='index')
print(emotion_df)
# Out:
#                 0
# joy           416
# positive      710
# trust         420
# anticipation  302
# surprise      168
# negative      240
# sadness       119
# disgust        97
# fear          104
# anger         101

# %%
emotion_df = emotion_df.reset_index()
emotion_df = emotion_df.rename(columns={'index' : 'Emotion Classification' , 0: 'Emotion Count'})
emotion_df = emotion_df.sort_values(by=['Emotion Count'], ascending=False)
emotion_df.head()
# Out:
#   Emotion Classification  Emotion Count
# 1               positive            710
# 2                  trust            420
# 0                    joy            416
# 3           anticipation            302
# 5               negative            240

# %%
import plotly.express as px
fig = px.bar(emotion_df, x='Emotion Count', y='Emotion Classification', color = 'Emotion Classification', orientation='h', width = 800, height = 400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b602d8c4-0fa5-49f1-933e-42b038c523a4" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b602d8c4-0fa5-49f1-933e-42b038c523a4")) {                    Plotly.newPlot(                        "b602d8c4-0fa5-49f1-933e-42b038c523a4",                        [{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"positive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"positive","offsetgroup":"positive","orientation":"h","showlegend":true,"textposition":"auto","x":[710],"xaxis":"x","y":["positive"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"trust","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"trust","offsetgroup":"trust","orientation":"h","showlegend":true,"textposition":"auto","x":[420],"xaxis":"x","y":["trust"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"joy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"joy","offsetgroup":"joy","orientation":"h","showlegend":true,"textposition":"auto","x":[416],"xaxis":"x","y":["joy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"anticipation","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"anticipation","offsetgroup":"anticipation","orientation":"h","showlegend":true,"textposition":"auto","x":[302],"xaxis":"x","y":["anticipation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"negative","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"negative","offsetgroup":"negative","orientation":"h","showlegend":true,"textposition":"auto","x":[240],"xaxis":"x","y":["negative"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"surprise","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"surprise","offsetgroup":"surprise","orientation":"h","showlegend":true,"textposition":"auto","x":[168],"xaxis":"x","y":["surprise"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"sadness","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"sadness","offsetgroup":"sadness","orientation":"h","showlegend":true,"textposition":"auto","x":[119],"xaxis":"x","y":["sadness"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"fear","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"fear","offsetgroup":"fear","orientation":"h","showlegend":true,"textposition":"auto","x":[104],"xaxis":"x","y":["fear"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"anger","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"anger","offsetgroup":"anger","orientation":"h","showlegend":true,"textposition":"auto","x":[101],"xaxis":"x","y":["anger"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Emotion Classification=%{y}<br>Emotion Count=%{x}<extra></extra>","legendgroup":"disgust","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"disgust","offsetgroup":"disgust","orientation":"h","showlegend":true,"textposition":"auto","x":[97],"xaxis":"x","y":["disgust"],"yaxis":"y","type":"b ...

# %%
affect_df = pd.DataFrame.from_dict(text_object.affect_dict, orient='index')

# %%
affect_df.head()
# Out:
#                   0         1         2         3      4     5     6     7  \
# food            joy  positive     trust      None   None  None  None  None
# found           joy  positive     trust      None   None  None  None  None
# good   anticipation       joy  positive  surprise  trust  None  None  None
# small      negative      None      None      None   None  None  None  None
# error      negative   sadness      None      None   None  None  None  None
#
#           8     9
# food   None  None
# found  None  None
# good   None  None
# small  None  None
# error  None  None

# %%
freq = pd.DataFrame.from_dict(text_object.affect_frequencies, orient='index')
print(freq)
# Out:
#                      0
# fear          0.038849
# anger         0.037729
# anticip       0.000000
# trust         0.156892
# surprise      0.062757
# positive      0.265222
# negative      0.089653
# sadness       0.044453
# disgust       0.036235
# joy           0.155398
# anticipation  0.112813

# %%
# !pip install text2emotion
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting text2emotion
#   Downloading text2emotion-0.0.5-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.4 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from text2emotion) (3.2.5)
# Collecting emoji>=0.6.0
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 36.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->text2emotion) (1.15.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=61558f4a9741c834b91d0de22c6127812590cc335193106b29698d7d88723c65
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji, text2emotion
# Successfully installed emoji-1.7.0 text2emotion-0.0.5

# %%
text = "I was asked to sign a third party contract a week out from stay. If it wasn't an 8 person group that took a lot of wrangling I would have cancelled the booking straight away. Bathrooms - there are no stand alone bathrooms. Please consider this - you have to clear out the main bedroom to use that bathroom. Other option is you walk through a different bedroom to get to its en-suite. Signs all over the apartment - there are signs everywhere - some helpful - some telling you rules. Perhaps some people like this but It negatively affected our enjoyment of the accommodation. Stairs - lots of them - some had slightly bending wood which caused a minor injury."

# %%
#Import the modules
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#Call to the function
te.get_emotion(text)
# Out:
# {'Angry': 0.12, 'Fear': 0.42, 'Happy': 0.04, 'Sad': 0.33, 'Surprise': 0.08}

# %%
emo_te= [] 
for i in df["Text"].values.tolist():
  emotion = te.get_emotion(i)
  print(emotion) 
  keymax =max(emotion, key=emotion.get)
  emo_te.append(keymax)
print(emo_te)
# Out:
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.0, 'Fear': 0.17}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.33}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.67, 'Sad': 0.17, 'Fear': 0.17}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.25, 'Fear': 0.25}
# {'Happy': 0.67, 'Angry': 0.33, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.36, 'Angry': 0.0, 'Surprise': 0.18, 'Sad': 0.18, 'Fear': 0.27}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.67}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.24, 'Angry': 0.1, 'Surprise': 0.19, 'Sad': 0.38, 'Fear': 0.1}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.38, 'Sad': 0.5, 'Fear': 0.12}
# {'Happy': 0.09, 'Angry': 0.0, 'Surprise': 0.27, 'Sad': 0.36, 'Fear': 0.27}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.25}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.29, 'Angry': 0.14, 'Surprise': 0.14, 'Sad': 0.0, 'Fear': 0.43}
# {'Happy': 0.33, 'Angry': 0.17, 'Surprise': 0.17, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.67}
# {'Happy': 0.12, 'Angry': 0.0, 'Surprise': 0.06, 'Sad': 0.56, 'Fear': 0.25}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.75, 'Fear': 0.25}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.67, 'Fear': 0.0}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.4, 'Fear': 0.4}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 1.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.5, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.5, 'Angry': 0.25, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.0}
# {'Happy': 0.33, 'Angry': 0.06, 'Surprise': 0.22, 'Sad': 0.11, 'Fear': 0.28}
# {'Happy': 0.24, 'Angry': 0.1, 'Surprise': 0.19, 'Sad': 0.38, 'Fear': 0.1}
# {'Happy': 0.27, 'Angry': 0.0, 'Surprise': 0.27, 'Sad': 0.09, 'Fear': 0.36}
# {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.25}
# {'Happy': 0.16, 'Angry': 0.05, 'Surprise': 0.21, 'Sad': 0.26, 'Fear': 0.33}
# {'Happy': 0.14, 'Angry': 0.0, 'Surprise': 0.38, 'Sad': 0.24, 'Fear': 0.24}
# {'Happy': 0.24, 'Angry': 0.06, 'Surprise': 0.18, 'Sad': 0.24, 'Fear': 0.29}
# {'Happy': 0.1, 'Angry': 0.0, 'Surprise': 0.1, 'Sad': 0.4, 'Fear': 0.4}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.12, 'Angry': 0.0, 'Surprise': 0.12, 'Sad': 0.38, 'Fear': 0.38}
# {'Happy': 0.29, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.14, 'Fear': 0.43}
# {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.2}
# {'Happy': 0.27, 'Angry': 0.08, 'Surprise': 0.31, 'Sad': 0.31, 'Fear': 0.04}
# {'Happy': 0.14, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.39, 'Fear': 0.33}
# {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.25}
# {'Happy': 0.57, 'Angry': 0.14, 'Surprise': 0.0, 'Sad': 0.14, 'Fear': 0.14}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.38, 'Sad': 0.12, 'Fear': 0.25}
# {'Happy': 0.14, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.43, 'Fear': 0.29}
# {'Happy': 0.17, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.25, 'Fear': 0.25}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.11, 'Angry': 0.11, 'Surprise': 0.11, 'Sad': 0.67, 'Fear': 0.0}
# {'Happy': 0.5, 'Angry': 0.5, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.33, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.33}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.56, 'Fear': 0.11}
# {'Happy': 0.09, 'Angry': 0.04, 'Surprise': 0.09, 'Sad': 0.22, 'Fear': 0.57}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 1.0}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.25, 'Fear': 0.08}
# {'Happy': 0.18, 'Angry': 0.09, 'Surprise': 0.36, 'Sad': 0.18, 'Fear': 0.18}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.0, 'Fear': 0.25}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.3, 'Sad': 0.4, 'Fear': 0.1}
# {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.25}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.36, 'Angry': 0.0, 'Surprise': 0.08, 'Sad': 0.32, 'Fear': 0.24}
# {'Happy': 0.0, 'Angry': 0.12, 'Surprise': 0.38, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.14, 'Angry': 0.14, 'Surprise': 0.14, 'Sad': 0.14, 'Fear': 0.43}
# {'Happy': 0.11, 'Angry': 0.05, 'Surprise': 0.16, 'Sad': 0.16, 'Fear': 0.53}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.33}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.75, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.5}
# {'Happy': 0.07, 'Angry': 0.14, 'Surprise': 0.07, 'Sad': 0.29, 'Fear': 0.43}
# {'Happy': 0.26, 'Angry': 0.04, 'Surprise': 0.17, 'Sad': 0.48, 'Fear': 0.04}
# {'Happy': 0.55, 'Angry': 0.0, 'Surprise': 0.36, 'Sad': 0.0, 'Fear': 0.09}
# {'Happy': 0.11, 'Angry': 0.15, 'Surprise': 0.19, 'Sad': 0.28, 'Fear': 0.28}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 1.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 1.0}
# {'Happy': 0.23, 'Angry': 0.0, 'Surprise': 0.15, 'Sad': 0.23, 'Fear': 0.38}
# {'Happy': 0.54, 'Angry': 0.0, 'Surprise': 0.15, 'Sad': 0.08, 'Fear': 0.23}
# {'Happy': 0.57, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.0, 'Fear': 0.29}
# {'Happy': 0.75, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.0}
# {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.0, 'Fear': 0.4}
# {'Happy': 0.29, 'Angry': 0.14, 'Surprise': 0.14, 'Sad': 0.0, 'Fear': 0.43}
# {'Happy': 0.16, 'Angry': 0.02, 'Surprise': 0.18, 'Sad': 0.41, 'Fear': 0.23}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.29, 'Sad': 0.43, 'Fear': 0.29}
# {'Happy': 0.11, 'Angry': 0.11, 'Surprise': 0.56, 'Sad': 0.0, 'Fear': 0.22}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.12, 'Fear': 0.38}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.6}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.6, 'Sad': 0.2, 'Fear': 0.0}
# {'Happy': 0.06, 'Angry': 0.0, 'Surprise': 0.18, 'Sad': 0.35, 'Fear': 0.41}
# {'Happy': 0.3, 'Angry': 0.1, 'Surprise': 0.1, 'Sad': 0.2, 'Fear': 0.3}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.75}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# {'Happy': 0.33, 'Angry': 0.17, 'Surprise': 0.17, 'Sad': 0.17, 'Fear': 0.17}
# {'Happy': 0.19, 'Angry': 0.12, 'Surprise': 0.19, 'Sad': 0.19, 'Fear': 0.31}
# {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.33}
# {'Happy': 0.24, 'Angry': 0.1, 'Surprise': 0.1, 'Sad': 0.19, 'Fear': 0.38}
# {'Happy': 0.29, 'Angry': 0.14, 'Surprise': 0.14, 'Sad': 0.0, 'Fear': 0.43}
# {'Happy': 0.2, 'Angry': 0.1, 'Surprise': 0.2, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.8}
# {'Happy': 0.12, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.38, 'Fear': 0.25}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.1, 'Fear': 0.3}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.4, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.58, 'Sad': 0.0, 'Fear': 0.17}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.17, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.0, 'Fear': 0.58}
# {'Happy': 0.62, 'Angry': 0.25, 'Surprise': 0.0, 'Sad': 0.12, 'Fear': 0.0}
# {'Happy': 0.27, 'Angry': 0.05, 'Surprise': 0.32, 'Sad': 0.23, 'Fear': 0.14}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.5, 'Fear': 0.0}
# {'Happy': 0.43, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.14, 'Fear': 0.29}
# {'Happy': 0.26, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.23, 'Fear': 0.37}
# {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.4, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.43, 'Angry': 0.14, 'Surprise': 0.0, 'Sad': 0.14, 'Fear': 0.29}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 1.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.43, 'Angry': 0.0, 'Surprise': 0.07, 'Sad': 0.07, 'Fear': 0.43}
# {'Happy': 0.1, 'Angry': 0.13, 'Surprise': 0.19, 'Sad': 0.26, 'Fear': 0.32}
# {'Happy': 0.26, 'Angry': 0.05, 'Surprise': 0.11, 'Sad': 0.26, 'Fear': 0.32}
# {'Happy': 0.3, 'Angry': 0.0, 'Surprise': 0.3, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.07, 'Sad': 0.47, 'Fear': 0.47}
# {'Happy': 0.08, 'Angry': 0.0, 'Surprise': 0.08, 'Sad': 0.46, 'Fear': 0.38}
# {'Happy': 0.13, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.07, 'Fear': 0.6}
# {'Happy': 0.08, 'Angry': 0.08, 'Surprise': 0.25, 'Sad': 0.25, 'Fear': 0.33}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.5, 'Fear': 0.25}
# {'Happy': 0.29, 'Angry': 0.0, 'Surprise': 0.29, 'Sad': 0.29, 'Fear': 0.14}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.17}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.12, 'Sad': 0.25, 'Fear': 0.38}
# {'Happy': 0.11, 'Angry': 0.11, 'Surprise': 0.11, 'Sad': 0.44, 'Fear': 0.22}
# {'Happy': 0.0, 'Angry': 0.2, 'Surprise': 0.4, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.43, 'Angry': 0.14, 'Surprise': 0.29, 'Sad': 0.14, 'Fear': 0.0}
# {'Happy': 0.17, 'Angry': 0.33, 'Surprise': 0.17, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.12, 'Sad': 0.25, 'Fear': 0.38}
# {'Happy': 1.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.44, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.22}
# {'Happy': 0.11, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.22}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.6, 'Fear': 0.2}
# {'Happy': 0.12, 'Angry': 0.12, 'Surprise': 0.41, 'Sad': 0.06, 'Fear': 0.29}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.14, 'Fear': 0.71}
# {'Happy': 0.62, 'Angry': 0.0, 'Surprise': 0.12, 'Sad': 0.25, 'Fear': 0.0}
# {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.0, 'Fear': 0.4}
# {'Happy': 0.62, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.12}
# {'Happy': 0.0, 'Angry': 0.12, 'Surprise': 0.12, 'Sad': 0.38, 'Fear': 0.38}
# {'Happy': 0.44, 'Angry': 0.11, 'Surprise': 0.44, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.04, 'Angry': 0.09, 'Surprise': 0.26, 'Sad': 0.22, 'Fear': 0.39}
# {'Happy': 0.0, 'Angry': 0.33, 'Surprise': 0.17, 'Sad': 0.17, 'Fear': 0.33}
# {'Happy': 0.38, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.25, 'Fear': 0.12}
# {'Happy': 0.29, 'Angry': 0.0, 'Surprise': 0.14, 'Sad': 0.43, 'Fear': 0.14}
# {'Happy': 0.38, 'Angry': 0.0, 'Surprise': 0.12, 'Sad': 0.12, 'Fear': 0.38}
# {'Happy': 0.4, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.2, 'Fear': 0.4}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.0, 'Fear': 0.17}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.44, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.0, 'Fear': 0.22}
# {'Happy': 0.27, 'Angry': 0.0, 'Surprise': 0.18, 'Sad': 0.36, 'Fear': 0.18}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# {'Happy': 0.25, 'Angry': 0.12, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.38}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.57, 'Sad': 0.29, 'Fear': 0.14}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.25, 'Fear': 0.25}
# {'Happy': 0.3, 'Angry': 0.0, 'Surprise': 0.1, 'Sad': 0.4, 'Fear': 0.2}
# {'Happy': 0.2, 'Angry': 0.2, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.2}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.6, 'Sad': 0.2, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.11, 'Surprise': 0.22, 'Sad': 0.44, 'Fear': 0.22}
# {'Happy': 0.17, 'Angry': 0.17, 'Surprise': 0.5, 'Sad': 0.17, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.08, 'Surprise': 0.17, 'Sad': 0.33, 'Fear': 0.42}
# {'Happy': 0.43, 'Angry': 0.29, 'Surprise': 0.0, 'Sad': 0.14, 'Fear': 0.14}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.0, 'Fear': 0.5}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.14, 'Fear': 0.86}
# {'Happy': 0.33, 'Angry': 0.33, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.2, 'Angry': 0.0, 'Surprise': 0.4, 'Sad': 0.4, 'Fear': 0.0}
# {'Happy': 0.07, 'Angry': 0.07, 'Surprise': 0.41, 'Sad': 0.19, 'Fear': 0.26}
# {'Happy': 0.25, 'Angry': 0.11, 'Surprise': 0.11, 'Sad': 0.32, 'Fear': 0.21}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.25, 'Sad': 0.25, 'Fear': 0.5}
# {'Happy': 0.2, 'Angry': 0.2, 'Surprise': 0.0, 'Sad': 0.6, 'Fear': 0.0}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.33, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.15, 'Angry': 0.23, 'Surprise': 0.08, 'Sad': 0.23, 'Fear': 0.31}
# {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.4, 'Fear': 0.0}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.0, 'Fear': 0.17}
# {'Happy': 0.08, 'Angry': 0.15, 'Surprise': 0.35, 'Sad': 0.12, 'Fear': 0.31}
# {'Happy': 0.22, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.44, 'Fear': 0.17}
# {'Happy': 0.33, 'Angry': 0.17, 'Surprise': 0.17, 'Sad': 0.33, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.5, 'Fear': 0.0}
# {'Happy': 0.15, 'Angry': 0.02, 'Surprise': 0.22, 'Sad': 0.35, 'Fear': 0.26}
# {'Happy': 0.25, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.25, 'Fear': 0.5}
# {'Happy': 0.43, 'Angry': 0.14, 'Surprise': 0.14, 'Sad': 0.0, 'Fear': 0.29}
# {'Happy': 0.2, 'Angry': 0.2, 'Surprise': 0.2, 'Sad': 0.2, 'Fear': 0.2}
# {'Happy': 0.6, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.2, 'Fear': 0.0}
# {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.17, 'Sad': 0.17, 'Fear': 0.17}
# {'Happy': 0.33, 'Angry': 0.08, 'Surprise': 0.17, 'Sad': 0.0, 'Fear': 0.42}
# {'Happy': 0.31, 'Angry': 0.0, 'Surprise': 0.38, 'Sad': 0.0, 'Fear': 0.31}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 1.0, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.67, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.33}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 1.0, 'Fear': 0.0}
# {'Happy': 0.33, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.33, 'Fear': 0.33}
# {'Happy': 0.8, 'Angry': 0.0, 'Surprise': 0.2, 'Sad': 0.0, 'Fear': 0.0}
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.5}
# ['Surprise', 'Surprise', 'Surprise', 'Happy', 'Happy', 'Happy', 'Happy', 'Fear', 'Fear', 'Happy', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy', 'Fear', 'Happy', 'Fear', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy', 'Happy', 'Sad', 'Surprise', 'Angry', 'Happy', 'Happy', 'Sad', 'Fear', 'Happy', 'Fear', 'Surprise', 'Fear', 'Sad', 'Happy', 'Sad', 'Fear', 'Happy', 'Surprise', 'Sad', 'Happy', 'Happy', 'Surprise', 'Sad', 'Surprise', 'Happy', 'Sad', 'Happy', 'Angry', 'Sad', 'Fear', 'Fear', 'Happy', 'Surprise', 'Surprise', 'Sad', 'Happy', 'Happy', 'Fear', 'Happy', 'Happy', 'Happy', 'Fear', 'Fear', 'Fear', 'Happy', 'Sad', 'Sad', 'Fear', 'Sad', 'Happy', 'Sad', 'Fear', 'Fear', 'Fear', 'Happy', 'Happy', 'Happy', 'Happy', 'Fear', 'Sad', 'Sad', 'Surprise', 'Happy', 'Fear', 'Surprise', 'Fear', 'Happy', 'Fear', 'Happy', 'Happy', 'Fear', 'Happy', 'Happy', 'Fear', 'Fear', 'Fear', 'Fear', 'Sad', 'Fear', 'Happy', 'Surprise', 'Happy', 'Surprise', 'Happy', 'Fear', 'Happy', 'Surprise', 'Surprise', 'Happy', 'Fear', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Fear', 'Fear', 'Happy', 'Sad', 'Sad', 'Fear', 'Fear', 'Sad', 'Happy', 'Happy', 'Fear', 'Sad', 'Surprise', 'Happy', 'Angry', 'Fear', 'Happy', 'Happy', 'Surprise', 'Happy', 'Sad', 'Surprise', 'Fear', 'Happy', 'Happy', 'Happy', 'Sad', 'Happy', 'Fear', 'Angry', 'Happy', 'Sad', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Sad', 'Surprise', 'Happy', 'Fear', 'Surprise', 'Happy', 'Happy', 'Sad', 'Sad', 'Surprise', 'Sad', 'Surprise', 'Fear', 'Happy', 'Fear', 'Fear', 'Happy', 'Surprise', 'Surprise', 'Sad', 'Fear', 'Sad', 'Happy', 'Happy', 'Fear', 'Happy', 'Happy', 'Surprise', 'Sad', 'Happy', 'Surprise', 'Sad', 'Fear', 'Happy', 'Happy', 'Happy', 'Happy', 'Fear', 'Surprise', 'Surprise', 'Happy', 'Sad', 'Happy', 'Happy', 'Sad']

# %%
df['Text2emotion']= emo_te 
df
# Out:
#       Id   ProductId          UserId                      ProfileName  \
# 0      1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1      2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2      3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3      4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4      5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ..   ...         ...             ...                              ...
# 195  196  B0028C44Z0  A3B6S35IUGOGW4                           Rutt10
# 196  197  B0028C44Z0   AI7O5C9KBVSTF                i&#60;3pnutbutter
# 197  198  B0028C44Z0   A4LL4KXLRBQHQ                  stillgoinstrong
# 198  199  B0028C44Z0  A3U94LRA4I8YAL   Brenda Woodward "love to read"
# 199  200  B0028C44Z0  A1WTXY4MW3YDF2                           Gordon
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                       1                       1      5  1303862400
# 1                       0                       0      1  1346976000
# 2                       1                       1      4  1219017600
# 3                       3                       3      2  1307923200
# 4                       0                       0      5  1350777600
# ..                    ...                     ...    ...         ...
# 195                     1                       1      5  1300406400
# 196                     3                       4      5  1274054400
# 197                     2                       3      3  1278460800
# 198                     2                       3      5  1265932800
# 199                     0                       0      5  1344729600
#
#                         Summary  \
# 0         Good Quality Dog Food
# 1             Not as Advertised
# 2         "Delight" says it all
# 3                Cough Medicine
# 4                   Great taffy
# ..                          ...
# 195     Altoids mini mints tins
# 196  Altoids Smalls-Wintergreen
# 197                Sugarfree...
# 198                     Tasty!!
# 199    These mints are awesome!
#
#                                                   Text Text2emotion
# 0    I have bought several of the Vitality canned d...     Surprise
# 1    Product arrived labeled as Jumbo Salted Peanut...     Surprise
# 2    This is a confection that has been around a fe...     Surprise
# 3    If you are looking for the secret ingredient i...        Happy
# 4    Great taffy at a great price.  There was a wid...        Happy
# ..                                                 ...          ...
# 195  These little tins of sugar free mine mints wer...        Happy
# 196  Pros:<br />+packaging, shipping, price<br />+s...          Sad
# 197  Be careful not to eat too many of them in one ...        Happy
# 198  These mints are really strong and have a great...        Happy
# 199  This is a huge supply of them. I'm still worki...          Sad
#
# [200 rows x 11 columns]

# %%
emo_nrclex=[]
for i in df["Text"].values.tolist():
  text_object = NRCLex(i)
  emotion= text_object.affect_frequencies
  # print(emo_nrclex)
  keymax =max(emotion, key=emotion.get)
  emo_nrclex.append(keymax)
# print(emo_nrclex)

# %%
#adding result as a column in our dataframe
df['NRCLEX']= emo_nrclex 
display(df)
df['NRCLEX'].describe() #to see the bias towards sentiment: positive
# Out:
#       Id   ProductId          UserId                      ProfileName  \
# 0      1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1      2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2      3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3      4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4      5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ..   ...         ...             ...                              ...
# 195  196  B0028C44Z0  A3B6S35IUGOGW4                           Rutt10
# 196  197  B0028C44Z0   AI7O5C9KBVSTF                i&#60;3pnutbutter
# 197  198  B0028C44Z0   A4LL4KXLRBQHQ                  stillgoinstrong
# 198  199  B0028C44Z0  A3U94LRA4I8YAL   Brenda Woodward "love to read"
# 199  200  B0028C44Z0  A1WTXY4MW3YDF2                           Gordon
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                       1                       1      5  1303862400
# 1                       0                       0      1  1346976000
# 2                       1                       1      4  1219017600
# 3                       3                       3      2  1307923200
# 4                       0                       0      5  1350777600
# ..                    ...                     ...    ...         ...
# 195                     1                       1      5  1300406400
# 196                     3                       4      5  1274054400
# 197                     2                       3      3  1278460800
# 198                     2                       3      5  1265932800
# 199                     0                       0      5  1344729600
#
#                         Summary  \
# 0         Good Quality Dog Food
# 1             Not as Advertised
# 2         "Delight" says it all
# 3                Cough Medicine
# 4                   Great taffy
# ..                          ...
# 195     Altoids mini mints tins
# 196  Altoids Smalls-Wintergreen
# 197                Sugarfree...
# 198                     Tasty!!
# 199    These mints are awesome!
#
#                                                   Text Text2emotion    NRCLEX
# 0    I have bought several of the Vitality canned d...     Surprise     trust
# 1    Product arrived labeled as Jumbo Salted Peanut...     Surprise  negative
# 2    This is a confection that has been around a fe...     Surprise  positive
# 3    If you are looking for the secret ingredient i...        Happy     trust
# 4    Great taffy at a great price.  There was a wid...        Happy     trust
# ..                                                 ...          ...       ...
# 195  These little tins of sugar free mine mints wer...        Happy  positive
# 196  Pros:<br />+packaging, shipping, price<br />+s...          Sad     trust
# 197  Be careful not to eat too many of them in one ...        Happy  positive
# 198  These mints are really strong and have a great...        Happy  positive
# 199  This is a huge supply of them. I'm still worki...          Sad  positive
#
# [200 rows x 12 columns]
# count          200
# unique           7
# top       positive
# freq           131
# Name: NRCLEX, dtype: object
