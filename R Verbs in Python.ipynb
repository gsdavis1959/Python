# %%
# !pip install siuba
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\gsdav\anaconda3\envs\tensorflow\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\gsdav\\AppData\\Local\\Temp\\pip-install-3t5m6ntd\\siuba_1b20f3b6dac64fd7b0dc884d697e31bf\\setup.py'"'"'; __file__='"'"'C:\\Users\\gsdav\\AppData\\Local\\Temp\\pip-install-3t5m6ntd\\siuba_1b20f3b6dac64fd7b0dc884d697e31bf\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\gsdav\AppData\Local\Temp\pip-pip-egg-info-pkyc5x_t'
#          cwd: C:\Users\gsdav\AppData\Local\Temp\pip-install-3t5m6ntd\siuba_1b20f3b6dac64fd7b0dc884d697e31bf\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
# ...

# %%
import numpy as np
import pandas as pd
from siuba import _
from siuba.dply.verbs import group_by, mutate, select, summarize, ungroup

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gsdavis1959/Data/master/HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df_attrition = df >> \
    group_by('Attrition') >> \
    summarize(
            mean_daily_rate = np.mean(_.DailyRate))

# %%
df_attrition
# Out:
#   Attrition  mean_daily_rate
# 0        No       812.504461
# 1       Yes       750.362869
